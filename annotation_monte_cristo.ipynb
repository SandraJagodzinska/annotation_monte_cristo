# %% [markdown]
# # Annotation automatique : Le comte de Monte-Cristo
# Dans le cadre de notre projet, nous avons décidé d'annoter un extrait de l'oeuvre célèbre de Dumas, *Le comte de Monte-Cristo* (1846). L'objectif est d'évaluer deux annotateurs automatiques de notre choix : on évaluera ici le module de Python, Spacy, ainsi que les annotateurs SEM et Treetagger.

# %%
# import modules
import spacy
import csv
import pandas as pd

from spacy.lang.fr import French
from spacy.tokens import Doc
from spacy.tokens import Span
from spacy import displacy

# %% [markdown]
# ## Résultats
# Afin de calculer les résultats qui nous intéressaient (c'est-à-dire, la précision, le rappel, et la f-mesure), nous avons implémenté trois fonctions :
# - `conf_matrix` : prend en argument les tokens de l'annotateur automatiques, les tokens du gold, `cat_s` qui est égale à la chaîne de caractère correspondant à la catégorie évaluée (par ex.: *POS* ou *lemma*), ainsi que les résultats de l'annotateur et du gold pour cette annotation. Dans le cas où on veut obtenir la matrice de confusion pour le *POS-tagging*, on appelera la fonction ainsi : `conf_matrix(token, token_gold, "POS", pos, pos_gold)`. La fonction permet un affichage des données, ce qui permet à l'utilisateur un aperçu visuel des différences entre les deux annotateurs. Le code prend en compte la différence de tokenisation entre l'annotateur automatique et le gold. Pour plus d'explication, voir le rapport. La fonction renvoie les vrai positifs, faux positifs, et faux négatifs.
# - `conf_matrix_token` : même principe que `conf_matrix`, à la différence qu'on prend en argument seulement ici les tokens de l'annotateur automatique et du gold. Mets en avant la différence de tokenisation. La fonction renvoie les vrai positifs, faux positifs, et faux négatifs.
# - `p_r_fscore` : prend en arguement vrai positif, faux positif, et faux négatif, et renvoie les valeurs de précision, rappel, et f-mesure.

# %%
# pos et lemma
def conf_matrix(token, token_gold, cat_s, cat, cat_gold):
    vp = 0
    fp = 0
    fn = 0

    for index, word in enumerate(pos):
        if token[index] == token_gold[index] and word == pos_gold[index]:
            vp += 1
        else:
            if cat_gold.isnull()[index] or word != cat_gold[index] and cat.notnull()[index]:
                fp += 1 
            elif cat.isnull()[index] or word != cat_gold[index] and cat_gold.notnull()[index]:
                fn += 1
            print(f'Token : {token[index]} | Token Gold : {token_gold[index]} | {cat_s} : {cat[index]} | {cat_s} Gold : {cat_gold[index]}')
    return vp, fp, fn

# %%
# token
def conf_matrix_token(token, token_gold):
    vp = 0
    fp = 0
    fn = 0

    for index, word in enumerate(token):
        if token[index] == token_gold[index]:
            vp += 1
        else:
            #when the tokens were divised not properly i was adding an empty row so we can compare row by row
            if token_gold.isnull()[index] or word != token_gold[index] and token.notnull()[index]:
                fp += 1 
            elif token.isnull()[index] or word != token_gold[index] and token_gold.notnull()[index]:
                fn += 1
            print(f'Token : {token[index]} | Token Gold : {token_gold[index]}')
    return vp, fp, fn

# %%
# calcul de r, p, et fscore
def p_r_fscore(vp, fp, fn):
    p = vp / (vp + fp)
    r = vp / (vp + fn)
    f = 2 * (p * r) / (p + r)
    return p, r, f

# %% [markdown]
# ## Annotation automatique avec Spacy

# %%
# french language model
nlp = spacy.load("fr_core_news_sm")
# read text file & preprocess
with open('monte_cristo.txt','r') as file:
    txt = file.read()
stripTxt = txt.replace('\n', ' ')

# %%
# apply language model to preprocessed text 
doc = nlp(stripTxt)

# %%
print(f"{'text':{8}} {'POS':{6}}{'lemma':{6}}{'TAG':{6}} {'Dep':{6}} {'POS explained':{20}} {'tag explained'} ")
for token in doc:
    print(f'{token.text:{8}} {token.pos_:{6}} {token.lemma_:{6}} {token.tag_:{6}} {token.dep_:{6}} {spacy.explain(token.pos_):{20}} {spacy.explain(token.tag_)}')
# Out:
# text     POS   lemma TAG    Dep    POS explained        tag explained
# ﻿Dantès  PUNCT  ﻿dantès PUNCT  nsubj  punctuation          punctuation
# resta    PRON   rester PRON   nmod   pronoun              pronoun
# confondu VERB   confondre VERB   ROOT   verb                 verb
# :        PUNCT  :      PUNCT  punct  punctuation          punctuation
# c'       PRON   ce     PRON   expl:subj pronoun              pronoun
# était    AUX    être   AUX    cop    auxiliary            auxiliary
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# en       ADP    en     ADP    case   adposition           adposition
# effet    NOUN   effet  NOUN   obl:mod noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# l'       DET    le     DET    det    determiner           determiner
# explication NOUN   explication NOUN   conj   noun                 noun
# de       ADP    de     ADP    case   adposition           adposition
# ce       PRON   ce     PRON   nmod   pronoun              pronoun
# qui      PRON   qui    PRON   nsubj  pronoun              pronoun
# s'       PRON   se     PRON   expl:comp pronoun              pronoun
# était    AUX    être   AUX    aux:tense auxiliary            auxiliary
# passé    VERB   passer VERB   acl:relcl verb                 verb
# à        ADP    à      ADP    case   adposition           adposition
# son      DET    son    DET    det    determiner           determiner
# insu     NOUN   insu   NOUN   obl:arg noun                 noun
# dans     ADP    dans   ADP    case   adposition           adposition
# son      DET    son    DET    det    determiner           determiner
# esprit   NOUN   esprit NOUN   nmod   noun                 noun
# ou       CCONJ  ou     CCONJ  cc     coordinating conjunction coordinating conjunction
# plutôt   ADV    plutôt ADV    conj   adverb               adverb
# dans     ADP    dans   ADP    case   adposition           adposition
# son      DET    son    DET    det    determiner           determiner
# âme      NOUN   âme    NOUN   obl:mod noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# car      CCONJ  car    CCONJ  cc     coordinating conjunction coordinating conjunction
# il       PRON   il     PRON   expl:subj pronoun              pronoun
# y        PRON   y      PRON   expl:comp pronoun              pronoun
# a        VERB   avoir  VERB   advcl  verb                 verb
# des      DET    un     DET    det    determiner           determiner
# pensées  NOUN   pensée NOUN   obj    noun                 noun
# qui      PRON   qui    PRON   nsubj  pronoun              pronoun
# viennent VERB   venir  VERB   acl:relcl verb                 verb
# de       ADP    de     ADP    case   adposition           adposition
# la       DET    le     DET    det    determiner           determiner
# tête     NOUN   tête   NOUN   obl:arg noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# d'       DET    de     DET    det    determiner           determiner
# autres   ADJ    autre  ADJ    conj   adjective            adjective
# qui      PRON   qui    PRON   nsubj  pronoun              pronoun
# viennent VERB   venir  VERB   acl:relcl verb                 verb
# du       ADP    de     ADP    case   adposition           adposition
# coeur    NOUN   coeur  NOUN   obl:arg noun                 noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# «        NOUN   «      NOUN   punct  noun                 noun
# Et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# puis     CCONJ  pouvoir CCONJ  cc     coordinating conjunction coordinating conjunction
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# continua NOUN   continua NOUN   obl:mod noun                 noun
# Faria    ADJ    faria  ADJ    amod   adjective            adjective
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# depuis   ADP    depuis ADP    case   adposition           adposition
# tantôt   CCONJ  tantôt CCONJ  cc     coordinating conjunction coordinating conjunction
# douze    VERB   douze  VERB   obl:mod verb                 verb
# ans      ADJ    an     ADJ    flat:name adjective            adjective
# que      SCONJ  que    SCONJ  mark   subordinating conjunction subordinating conjunction
# je       PRON   je     PRON   nsubj  pronoun              pronoun
# suis     AUX    être   AUX    cop    auxiliary            auxiliary
# en       ADP    en     ADP    case   adposition           adposition
# prison   NOUN   prison NOUN   dep    noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# j'       PRON   je     PRON   nsubj  pronoun              pronoun
# ai       AUX    avoir  AUX    aux:tense auxiliary            auxiliary
# repassé  VERB   repasser VERB   conj   verb                 verb
# dans     ADP    dans   ADP    case   adposition           adposition
# mon      DET    mon    DET    det    determiner           determiner
# esprit   NOUN   esprit NOUN   obl:mod noun                 noun
# toutes   ADJ    tout   ADJ    amod   adjective            adjective
# les      DET    le     DET    det    determiner           determiner
# évasions NOUN   évasion NOUN   obj    noun                 noun
# célèbres ADJ    célèbre ADJ    amod   adjective            adjective
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# Je       PRON   je     PRON   nsubj  pronoun              pronoun
# n'       ADV    ne     ADV    advmod adverb               adverb
# ai       AUX    avoir  AUX    aux:tense auxiliary            auxiliary
# vu       VERB   voir   VERB   ROOT   verb                 verb
# réussir  VERB   réussir VERB   xcomp  verb                 verb
# que      SCONJ  que    SCONJ  mark   subordinating conjunction subordinating conjunction
# rarement ADV    rarement ADV    advmod adverb               adverb
# les      DET    le     DET    det    determiner           determiner
# évasions NOUN   évasion NOUN   ccomp  noun                 noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# Les      DET    le     DET    det    determiner           determiner
# évasions NOUN   évasion NOUN   ROOT   noun                 noun
# heureuses ADJ    heureux ADJ    amod   adjective            adjective
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# les      DET    le     DET    det    determiner           determiner
# évasions NOUN   évasion NOUN   conj   noun                 noun
# couronnées VERB   couronner VERB   acl    verb                 verb
# d'       ADP    de     ADP    case   adposition           adposition
# un       DET    un     DET    det    determiner           determiner
# plein    ADJ    plein  ADJ    amod   adjective            adjective
# succès   NOUN   succès NOUN   nmod   noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# sont     AUX    être   AUX    cop    auxiliary            auxiliary
# les      DET    le     DET    det    determiner           determiner
# évasions NOUN   évasion NOUN   conj   noun                 noun
# méditées VERB   méditer VERB   acl    verb                 verb
# avec     ADP    avec   ADP    case   adposition           adposition
# soin     NOUN   soin   NOUN   obl:mod noun                 noun
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# lentement ADV    lentement ADV    conj   adverb               adverb
# préparées VERB   préparer VERB   acl    verb                 verb
# ;        PUNCT  ;      PUNCT  punct  punctuation          punctuation
# c'       PRON   ce     PRON   nsubj  pronoun              pronoun
# est      AUX    être   AUX    cop    auxiliary            auxiliary
# ainsi    ADV    ainsi  ADV    cc     adverb               adverb
# que      SCONJ  que    SCONJ  fixed  subordinating conjunction subordinating conjunction
# le       DET    le     DET    det    determiner           determiner
# duc      NOUN   duc    NOUN   nsubj  noun                 noun
# de       ADP    de     ADP    case   adposition           adposition
# Beaufort PROPN  Beaufort PROPN  nmod   proper noun          proper noun
# s'       PRON   se     PRON   expl:comp pronoun              pronoun
# est      AUX    être   AUX    aux:tense auxiliary            auxiliary
# échappé  VERB   échapper VERB   ROOT   verb                 verb
# du       ADP    de     ADP    case   adposition           adposition
# château  NOUN   château NOUN   obl:arg noun                 noun
# de       ADP    de     ADP    case   adposition           adposition
# Vincennes NOUN   vincenne NOUN   nmod   noun                 noun
# ;        PUNCT  ;      PUNCT  punct  punctuation          punctuation
# l'       DET    le     DET    det    determiner           determiner
# abbé     NOUN   abbé   NOUN   ROOT   noun                 noun
# Dubuquoi ADV    dubuquoi ADV    nmod   adverb               adverb
# du       ADP    de     ADP    case   adposition           adposition
# Fort-l'Évêque NOUN   fort-l'évêque NOUN   nmod   noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# Latude   PROPN  Latude PROPN  conj   proper noun          proper noun
# de       ADP    de     ADP    case   adposition           adposition
# la       DET    le     DET    det    determiner           determiner
# Bastille PROPN  Bastille PROPN  nmod   proper noun          proper noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# Il       PRON   il     PRON   expl:subj pronoun              pronoun
# y        PRON   y      PRON   expl:comp pronoun              pronoun
# a        VERB   avoir  VERB   ROOT   verb                 verb
# encore   ADV    encore ADV    advmod adverb               adverb
# celles   ADJ    celle  ADJ    xcomp  adjective            adjective
# que      SCONJ  que    SCONJ  mark   subordinating conjunction subordinating conjunction
# le       DET    le     DET    det    determiner           determiner
# hasard   NOUN   hasard NOUN   nsubj  noun                 noun
# peut     VERB   pouvoir VERB   acl:relcl verb                 verb
# offrir   VERB   offrir VERB   xcomp  verb                 verb
# :        PUNCT  :      PUNCT  punct  punctuation          punctuation
# celles   PRON   celui  PRON   nsubj  pronoun              pronoun
# -là      PRON   -là    PRON   nsubj  pronoun              pronoun
# sont     AUX    être   AUX    cop    auxiliary            auxiliary
# les      DET    le     DET    det    determiner           determiner
# meilleures NOUN   meilleur NOUN   conj   noun                 noun
# ;        PUNCT  ;      PUNCT  punct  punctuation          punctuation
# attendons NOUN   attendon NOUN   ROOT   noun                 noun
# une      DET    un     DET    det    determiner           determiner
# occasion NOUN   occasion NOUN   obj    noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# croyez   NOUN   croyez NOUN   dep    noun                 noun
# -moi     PRON   moi    PRON   dep    pronoun              pronoun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# si       SCONJ  si     SCONJ  mark   subordinating conjunction subordinating conjunction
# cette    DET    ce     DET    det    determiner           determiner
# occasion NOUN   occasion NOUN   nsubj  noun                 noun
# se       PRON   se     PRON   expl:comp pronoun              pronoun
# présente VERB   présente VERB   conj   verb                 verb
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# profitons NOUN   profiton NOUN   obj    noun                 noun
# -en      PRON   -en    PRON   nsubj  pronoun              pronoun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Vous   PRON   --vous PRON   nsubj  pronoun              pronoun
# avez     AUX    avoir  AUX    aux:tense auxiliary            auxiliary
# pu       VERB   pouvoir VERB   ROOT   verb                 verb
# attendre VERB   attendre VERB   xcomp  verb                 verb
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# vous     PRON   vous   PRON   obl:mod pronoun              pronoun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# dit      VERB   dire   VERB   advcl  verb                 verb
# Dantès   PROPN  Dantès PROPN  obl:arg proper noun          proper noun
# en       ADP    en     ADP    case   adposition           adposition
# soupirant NOUN   soupirant NOUN   obl:mod noun                 noun
# ;        PUNCT  ;      PUNCT  punct  punctuation          punctuation
# ce       DET    ce     DET    det    determiner           determiner
# long     ADJ    long   ADJ    amod   adjective            adjective
# travail  NOUN   travail NOUN   nsubj  noun                 noun
# vous     PRON   vous   PRON   iobj   pronoun              pronoun
# faisait  VERB   faire  VERB   ROOT   verb                 verb
# une      DET    un     DET    det    determiner           determiner
# occupation NOUN   occupation NOUN   obj    noun                 noun
# de       ADP    de     ADP    case   adposition           adposition
# tous     ADJ    tout   ADJ    amod   adjective            adjective
# les      DET    le     DET    det    determiner           determiner
# instants NOUN   instant NOUN   nmod   noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# quand    SCONJ  quand  SCONJ  mark   subordinating conjunction subordinating conjunction
# vous     PRON   vous   PRON   nsubj  pronoun              pronoun
# n'       ADV    ne     ADV    advmod adverb               adverb
# aviez    VERB   avoir  VERB   conj   verb                 verb
# pas      ADV    pas    ADV    advmod adverb               adverb
# votre    DET    votre  DET    det    determiner           determiner
# travail  NOUN   travail NOUN   obj    noun                 noun
# pour     ADP    pour   ADP    mark   adposition           adposition
# vous     PRON   vous   PRON   iobj   pronoun              pronoun
# distraire ADJ    distrair ADJ    advcl  adjective            adjective
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# vous     PRON   vous   PRON   nsubj  pronoun              pronoun
# aviez    VERB   avoir  VERB   advcl  verb                 verb
# vos      DET    votre  DET    det    determiner           determiner
# espérances NOUN   espérance NOUN   obj    noun                 noun
# pour     ADP    pour   ADP    mark   adposition           adposition
# vous     PRON   vous   PRON   obj    pronoun              pronoun
# consoler VERB   consoler VERB   advcl  verb                 verb
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Puis   PRON   --puis PRON   aux:tense pronoun              pronoun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# dit      VERB   dire   VERB   ROOT   verb                 verb
# l'       DET    le     DET    det    determiner           determiner
# abbé     NOUN   abbé   NOUN   obj    noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# je       PRON   je     PRON   nsubj  pronoun              pronoun
# ne       ADV    ne     ADV    advmod adverb               adverb
# m'       PRON   me     PRON   expl:comp pronoun              pronoun
# occupais VERB   occuper VERB   advcl  verb                 verb
# point    VERB   poindre VERB   xcomp  verb                 verb
# qu'      SCONJ  que    SCONJ  mark   subordinating conjunction subordinating conjunction
# à        ADP    à      ADP    case   adposition           adposition
# cela     PRON   celer  PRON   dep    pronoun              pronoun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Que    PRON   --que  PRON   nsubj  pronoun              pronoun
# faisiez  ADV    faire  ADV    dep    adverb               adverb
# -vous    PRON   vous   PRON   nsubj  pronoun              pronoun
# donc     ADV    donc   ADV    advmod adverb               adverb
# ?        PUNCT  ?      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --J'     NUM    --J'   NUM    nummod numeral              numeral
# écrivais NOUN   écrivai NOUN   ROOT   noun                 noun
# ou       CCONJ  ou     CCONJ  cc     coordinating conjunction coordinating conjunction
# j'       PRON   je     PRON   conj   pronoun              pronoun
# étudiais PROPN  étudier PROPN  flat:name proper noun          proper noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --On     DET    --on   DET    nsubj  determiner           determiner
# vous     PRON   vous   PRON   obj    pronoun              pronoun
# donne    VERB   donne  VERB   ROOT   verb                 verb
# donc     ADV    donc   ADV    advmod adverb               adverb
# du       ADP    de     ADP    case   adposition           adposition
# papier   NOUN   papier NOUN   obl:arg noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# des      DET    un     DET    det    determiner           determiner
# plumes   NOUN   plume  NOUN   nmod   noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# de       ADP    de     ADP    det    adposition           adposition
# l'       DET    le     DET    fixed  determiner           determiner
# encre    NOUN   encre  NOUN   obj    noun                 noun
# ?        PUNCT  ?      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Non    PRON   --non  PRON   ROOT   pronoun              pronoun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# dit      VERB   dire   VERB   ROOT   verb                 verb
# l'       DET    le     DET    det    determiner           determiner
# abbé     NOUN   abbé   NOUN   obj    noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# mais     CCONJ  mais   CCONJ  cc     coordinating conjunction coordinating conjunction
# je       PRON   je     PRON   nsubj  pronoun              pronoun
# m'       PRON   me     PRON   expl:comp pronoun              pronoun
# en       VERB   en     VERB   conj   verb                 verb
# fais     NOUN   fai    NOUN   obj    noun                 noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Vous   PRON   --vous PRON   nsubj  pronoun              pronoun
# vous     PRON   vous   PRON   obj    pronoun              pronoun
# faites   VERB   faire  VERB   ROOT   verb                 verb
# du       ADP    de     ADP    case   adposition           adposition
# papier   NOUN   papier NOUN   obl:arg noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# des      DET    un     DET    det    determiner           determiner
# plumes   NOUN   plume  NOUN   conj   noun                 noun
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# de       ADP    de     ADP    det    adposition           adposition
# l'       DET    le     DET    fixed  determiner           determiner
# encre    NOUN   encre  NOUN   conj   noun                 noun
# ?        PUNCT  ?      PUNCT  punct  punctuation          punctuation
# s'       PRON   se     PRON   expl:comp pronoun              pronoun
# écria    NOUN   écria  NOUN   ROOT   noun                 noun
# Dantès   PROPN  Dantès PROPN  obj    proper noun          proper noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Oui    ADV    --oui  ADV    nummod adverb               adverb
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# »        PUNCT  »      PUNCT  ROOT   punctuation          punctuation
# Dantès   NOUN   dantè  NOUN   nmod   noun                 noun
# regarda  VERB   regarder VERB   acl    verb                 verb
# cet      DET    ce     DET    det    determiner           determiner
# homme    NOUN   homme  NOUN   obj    noun                 noun
# avec     ADP    avec   ADP    case   adposition           adposition
# admiration NOUN   admiration NOUN   nmod   noun                 noun
# ;        PUNCT  ;      PUNCT  punct  punctuation          punctuation
# seulement ADV    seulement ADV    advmod adverb               adverb
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# il       PRON   il     PRON   nsubj  pronoun              pronoun
# avait    VERB   avoir  VERB   ROOT   verb                 verb
# encore   ADV    encore ADV    advmod adverb               adverb
# peine    NOUN   peine  NOUN   obj    noun                 noun
# à        ADP    à      ADP    mark   adposition           adposition
# croire   VERB   croire VERB   xcomp  verb                 verb
# ce       PRON   ce     PRON   obj    pronoun              pronoun
# qu'      PRON   que    PRON   obj    pronoun              pronoun
# il       PRON   il     PRON   nsubj  pronoun              pronoun
# disait   VERB   dire   VERB   acl:relcl verb                 verb
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# Faria    NOUN   faria  NOUN   nsubj  noun                 noun
# s'       PRON   se     PRON   expl:comp pronoun              pronoun
# aperçut  VERB   apercevoir VERB   ROOT   verb                 verb
# de       ADP    de     ADP    case   adposition           adposition
# ce       DET    ce     DET    det    determiner           determiner
# léger    ADJ    léger  ADJ    amod   adjective            adjective
# doute    NOUN   doute  NOUN   obl:arg noun                 noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# «        PROPN  «      PROPN  punct  proper noun          proper noun
# Quand    SCONJ  quand  SCONJ  mark   subordinating conjunction subordinating conjunction
# vous     PRON   vous   PRON   nsubj  pronoun              pronoun
# viendrez VERB   venir  VERB   advcl  verb                 verb
# chez     ADP    chez   ADP    case   adposition           adposition
# moi      PRON   moi    PRON   obl:mod pronoun              pronoun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# lui      PRON   luire  PRON   iobj   pronoun              pronoun
# dit      VERB   dire   VERB   advcl  verb                 verb
# -il      PRON   il     PRON   dep    pronoun              pronoun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# je       PRON   je     PRON   nsubj  pronoun              pronoun
# vous     PRON   vous   PRON   iobj   pronoun              pronoun
# montrerai VERB   montrer VERB   ROOT   verb                 verb
# un       DET    un     DET    det    determiner           determiner
# ouvrage  NOUN   ouvrage NOUN   obj    noun                 noun
# entier   ADJ    entier ADJ    amod   adjective            adjective
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# résultat NOUN   résultat NOUN   obj    noun                 noun
# des      ADP    de     ADP    case   adposition           adposition
# pensées  NOUN   pensée NOUN   nmod   noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# des      DET    un     DET    det    determiner           determiner
# recherches NOUN   recherche NOUN   conj   noun                 noun
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# des      DET    un     DET    det    determiner           determiner
# réflexions NOUN   réflexion NOUN   conj   noun                 noun
# de       ADP    de     ADP    case   adposition           adposition
# toute    ADJ    tout   ADJ    amod   adjective            adjective
# ma       DET    mon    DET    det    determiner           determiner
# vie      NOUN   vie    NOUN   nmod   noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# que      PRON   que    PRON   mark   pronoun              pronoun
# j'       PRON   je     PRON   nsubj  pronoun              pronoun
# avais    VERB   avoir  VERB   ccomp  verb                 verb
# médité   VERB   méditer VERB   xcomp  verb                 verb
# à        ADP    à      ADP    case   adposition           adposition
# l'       DET    le     DET    det    determiner           determiner
# ombre    NOUN   ombre  NOUN   obl:arg noun                 noun
# du       ADP    de     ADP    case   adposition           adposition
# Colisée  PROPN  Colisée PROPN  nmod   proper noun          proper noun
# à        ADP    à      ADP    case   adposition           adposition
# Rome     PROPN  Rome   PROPN  nmod   proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# au       ADP    au     ADP    case   adposition           adposition
# pied     NOUN   pied   NOUN   obl:mod noun                 noun
# de       ADP    de     ADP    case   adposition           adposition
# la       DET    le     DET    det    determiner           determiner
# colonne  NOUN   colonne NOUN   nmod   noun                 noun
# Saint-Marc PROPN  Saint-Marc PROPN  nmod   proper noun          proper noun
# à        ADP    à      ADP    case   adposition           adposition
# Venise   PROPN  Venise PROPN  nmod   proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# sur      ADP    sur    ADP    case   adposition           adposition
# les      DET    le     DET    det    determiner           determiner
# bords    NOUN   bord   NOUN   obl:mod noun                 noun
# de       ADP    de     ADP    case   adposition           adposition
# l'       DET    le     DET    det    determiner           determiner
# Arno     PROPN  Arno   PROPN  nmod   proper noun          proper noun
# à        ADP    à      ADP    case   adposition           adposition
# Florence PROPN  Florence PROPN  nmod   proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# que      SCONJ  que    SCONJ  mark   subordinating conjunction subordinating conjunction
# je       PRON   je     PRON   nsubj  pronoun              pronoun
# ne       ADV    ne     ADV    advmod adverb               adverb
# me       PRON   me     PRON   expl:comp pronoun              pronoun
# doutais  VERB   douter VERB   conj   verb                 verb
# guère    ADV    guère  ADV    advmod adverb               adverb
# qu'      SCONJ  que    SCONJ  mark   subordinating conjunction subordinating conjunction
# un       DET    un     DET    det    determiner           determiner
# jour     NOUN   jour   NOUN   nsubj  noun                 noun
# mes      DET    mon    DET    det    determiner           determiner
# geôliers NOUN   geôlier NOUN   nmod   noun                 noun
# me       PRON   me     PRON   iobj   pronoun              pronoun
# laisseraient VERB   laisser VERB   ccomp  verb                 verb
# le       DET    le     DET    det    determiner           determiner
# loisir   NOUN   loisir NOUN   obj    noun                 noun
# d'       ADP    de     ADP    mark   adposition           adposition
# exécuter VERB   exécuter VERB   xcomp  verb                 verb
# entre    ADP    entrer ADP    case   adposition           adposition
# les      DET    le     DET    det    determiner           determiner
# quatre   NUM    quatre NUM    nummod numeral              numeral
# murs     NOUN   mur    NOUN   obl:mod noun                 noun
# du       ADP    de     ADP    case   adposition           adposition
# château  NOUN   château NOUN   nmod   noun                 noun
# d'       ADP    de     ADP    case   adposition           adposition
# If       PROPN  If     PROPN  nmod   proper noun          proper noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# C'       PRON   ce     PRON   nsubj  pronoun              pronoun
# est      AUX    être   AUX    cop    auxiliary            auxiliary
# un       DET    un     DET    det    determiner           determiner
# _        NOUN   _      NOUN   nsubj  noun                 noun
# Traité   NOUN   traité NOUN   nmod   noun                 noun
# sur      ADP    sur    ADP    case   adposition           adposition
# la       DET    le     DET    det    determiner           determiner
# possibilité NOUN   possibilité NOUN   nmod   noun                 noun
# d'       ADP    de     ADP    case   adposition           adposition
# une      DET    un     DET    det    determiner           determiner
# monarchie NOUN   monarchie NOUN   nmod   noun                 noun
# générale ADJ    général ADJ    amod   adjective            adjective
# en       ADP    en     ADP    case   adposition           adposition
# Italie_. PROPN  Italie_. PROPN  nmod   proper noun          proper noun
# Ce       PRON   ce     PRON   nsubj  pronoun              pronoun
# fera     VERB   faire  VERB   ROOT   verb                 verb
# un       DET    un     DET    det    determiner           determiner
# grand    ADJ    grand  ADJ    amod   adjective            adjective
# volume   NOUN   volume NOUN   obj    noun                 noun
# in       PROPN  in     PROPN  amod   proper noun          proper noun
# -        PROPN  -      PROPN  nmod   proper noun          proper noun
# quarto   PROPN  quarto PROPN  nmod   proper noun          proper noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Et     NOUN   --et   NOUN   nsubj  noun                 noun
# vous     PRON   vous   PRON   obj    pronoun              pronoun
# l'       PRON   le     PRON   obj    pronoun              pronoun
# avez     AUX    avoir  AUX    aux:tense auxiliary            auxiliary
# écrit    VERB   écrire VERB   ROOT   verb                 verb
# ?        PUNCT  ?      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Sur    NOUN   --sur  NOUN   ROOT   noun                 noun
# deux     NUM    deux   NUM    nummod numeral              numeral
# chemises NOUN   chemise NOUN   nmod   noun                 noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# J'       PRON   je     PRON   nsubj  pronoun              pronoun
# ai       AUX    avoir  AUX    aux:tense auxiliary            auxiliary
# inventé  VERB   inventer VERB   ROOT   verb                 verb
# une      DET    un     DET    det    determiner           determiner
# préparation NOUN   préparation NOUN   obj    noun                 noun
# qui      PRON   qui    PRON   nsubj  pronoun              pronoun
# rend     VERB   rendre VERB   acl:relcl verb                 verb
# le       DET    le     DET    det    determiner           determiner
# linge    NOUN   linge  NOUN   obj    noun                 noun
# lisse    ADJ    lisse  ADJ    amod   adjective            adjective
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# uni      PROPN  uni    PROPN  conj   proper noun          proper noun
# comme    ADP    comme  ADP    case   adposition           adposition
# le       DET    le     DET    det    determiner           determiner
# parchemin NOUN   parchemin NOUN   dep    noun                 noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Vous   PRON   --vous PRON   nsubj  pronoun              pronoun
# êtes     AUX    être   AUX    cop    auxiliary            auxiliary
# donc     ADV    donc   ADV    advmod adverb               adverb
# chimiste ADJ    chimist ADJ    ROOT   adjective            adjective
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Un     ADV    --un   ADV    ROOT   adverb               adverb
# peu      ADV    peu    ADV    fixed  adverb               adverb
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# J'       PRON   je     PRON   nsubj  pronoun              pronoun
# ai       AUX    avoir  AUX    aux:tense auxiliary            auxiliary
# connu    VERB   connaître VERB   advcl  verb                 verb
# Lavoisier PROPN  Lavoisier PROPN  obj    proper noun          proper noun
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# je       PRON   je     PRON   nsubj:pass pronoun              pronoun
# suis     AUX    être   AUX    aux:pass auxiliary            auxiliary
# lié      VERB   lier   VERB   conj   verb                 verb
# avec     ADP    avec   ADP    case   adposition           adposition
# Cabanis  PROPN  Cabanis PROPN  obl:mod proper noun          proper noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Mais   NUM    --Mais NUM    advmod numeral              numeral
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# pour     ADP    pour   ADP    case   adposition           adposition
# un       DET    un     DET    det    determiner           determiner
# pareil   ADJ    pareil ADJ    amod   adjective            adjective
# ouvrage  NOUN   ouvrage NOUN   obl:mod noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# il       PRON   il     PRON   expl:subj pronoun              pronoun
# vous     PRON   vous   PRON   iobj   pronoun              pronoun
# a        AUX    avoir  AUX    aux:tense auxiliary            auxiliary
# fallu    VERB   falloir VERB   ROOT   verb                 verb
# faire    VERB   faire  VERB   xcomp  verb                 verb
# des      DET    un     DET    det    determiner           determiner
# recherches NOUN   recherche NOUN   obj    noun                 noun
# historiques ADJ    historique ADJ    amod   adjective            adjective
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# Vous     PRON   vous   PRON   nsubj  pronoun              pronoun
# aviez    VERB   avoir  VERB   ROOT   verb                 verb
# donc     ADV    donc   ADV    advmod adverb               adverb
# des      DET    un     DET    case   determiner           determiner
# livres   NOUN   livre  NOUN   obj    noun                 noun
# ?        PUNCT  ?      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --À      NOUN   --à    NOUN   obl:mod noun                 noun
# Rome     PROPN  Rome   PROPN  nmod   proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# j'       PRON   je     PRON   nsubj  pronoun              pronoun
# avais    VERB   avoir  VERB   ROOT   verb                 verb
# à        ADP    à      ADP    advmod adposition           adposition
# peu      ADV    peu    ADV    fixed  adverb               adverb
# près     ADV    près   ADV    advmod adverb               adverb
# cinq     NUM    cinq   NUM    nummod numeral              numeral
# mille    DET    mille  DET    det    determiner           determiner
# volumes  NOUN   volume NOUN   obl:mod noun                 noun
# dans     ADP    dans   ADP    case   adposition           adposition
# ma       DET    mon    DET    det    determiner           determiner
# bibliothèque NOUN   bibliothèque NOUN   nmod   noun                 noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# À        ADP    à      ADP    case   adposition           adposition
# force    NOUN   force  NOUN   obl:mod noun                 noun
# de       ADP    de     ADP    case   adposition           adposition
# les      PRON   le     PRON   det    pronoun              pronoun
# lire     VERB   lire   VERB   nmod   verb                 verb
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# de       ADP    de     ADP    mark   adposition           adposition
# les      PRON   le     PRON   obj    pronoun              pronoun
# relire   VERB   relire VERB   conj   verb                 verb
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# j'       PRON   je     PRON   nsubj  pronoun              pronoun
# ai       AUX    avoir  AUX    aux:tense auxiliary            auxiliary
# découvert VERB   découvrir VERB   ROOT   verb                 verb
# qu'      SCONJ  que    SCONJ  dep    subordinating conjunction subordinating conjunction
# avec     ADP    avec   ADP    case   adposition           adposition
# cent     NUM    cent   NUM    nummod numeral              numeral
# cinquante NUM    cinquante NUM    nummod numeral              numeral
# ouvrages NOUN   ouvrage NOUN   dep    noun                 noun
# bien     ADV    bien   ADV    advmod adverb               adverb
# choisis  ADJ    choisir ADJ    amod   adjective            adjective
# on       PRON   on     PRON   nsubj  pronoun              pronoun
# a        AUX    avoir  AUX    cop    auxiliary            auxiliary
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# sinon    ADV    sinon  ADV    advmod adverb               adverb
# le       DET    le     DET    det    determiner           determiner
# résumé   NOUN   résumé NOUN   conj   noun                 noun
# complet  ADJ    complet ADJ    amod   adjective            adjective
# des      ADP    de     ADP    case   adposition           adposition
# connaissances NOUN   connaissance NOUN   nmod   noun                 noun
# humaines ADJ    humain ADJ    amod   adjective            adjective
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# du       ADP    de     ADP    advmod adposition           adposition
# moins    ADV    moins  ADV    fixed  adverb               adverb
# tout     ADJ    tout   ADJ    amod   adjective            adjective
# ce       PRON   ce     PRON   nmod   pronoun              pronoun
# qu'      PRON   que    PRON   obj    pronoun              pronoun
# il       PRON   il     PRON   expl:subj pronoun              pronoun
# est      AUX    être   AUX    cop    auxiliary            auxiliary
# utile    ADJ    utile  ADJ    acl:relcl adjective            adjective
# à        ADP    à      ADP    case   adposition           adposition
# un       DET    un     DET    det    determiner           determiner
# homme    NOUN   homme  NOUN   obl:arg noun                 noun
# de       ADP    de     ADP    mark   adposition           adposition
# savoir   VERB   savoir VERB   acl    verb                 verb
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# J'       PRON   je     PRON   nsubj  pronoun              pronoun
# ai       AUX    avoir  AUX    aux:tense auxiliary            auxiliary
# consacré VERB   consacrer VERB   ROOT   verb                 verb
# trois    NUM    trois  NUM    nummod numeral              numeral
# années   NOUN   année  NOUN   obj    noun                 noun
# de       ADP    de     ADP    case   adposition           adposition
# ma       DET    mon    DET    det    determiner           determiner
# vie      NOUN   vie    NOUN   nmod   noun                 noun
# à        ADP    à      ADP    mark   adposition           adposition
# lire     VERB   lire   VERB   acl    verb                 verb
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# à        ADP    à      ADP    mark   adposition           adposition
# relire   VERB   relire VERB   conj   verb                 verb
# ces      DET    ce     DET    det    determiner           determiner
# cent     NUM    cent   NUM    fixed  numeral              numeral
# cinquante NUM    cinquante NUM    nummod numeral              numeral
# volumes  NOUN   volume NOUN   obj    noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# de       ADP    de     ADP    case   adposition           adposition
# sorte    NOUN   sorte  NOUN   nmod   noun                 noun
# que      SCONJ  que    SCONJ  mark   subordinating conjunction subordinating conjunction
# je       PRON   je     PRON   nsubj  pronoun              pronoun
# les      PRON   le     PRON   obj    pronoun              pronoun
# savais   ADJ    savai  ADJ    acl:relcl adjective            adjective
# à        ADP    à      ADP    case   adposition           adposition
# peu      ADV    peu    ADV    fixed  adverb               adverb
# près     ADV    près   ADV    fixed  adverb               adverb
# par      ADP    par    ADP    case   adposition           adposition
# coeur    NOUN   coeur  NOUN   obl:mod noun                 noun
# lorsque  SCONJ  lorsque SCONJ  mark   subordinating conjunction subordinating conjunction
# j'       PRON   je     PRON   nsubj:pass pronoun              pronoun
# ai       AUX    avoir  AUX    aux:tense auxiliary            auxiliary
# été      AUX    être   AUX    aux:pass auxiliary            auxiliary
# arrêté   VERB   arrêter VERB   advcl  verb                 verb
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# Dans     ADP    dans   ADP    case   adposition           adposition
# ma       DET    mon    DET    det    determiner           determiner
# prison   NOUN   prison NOUN   obl:mod noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# avec     ADP    avec   ADP    case   adposition           adposition
# un       DET    un     DET    det    determiner           determiner
# léger    ADJ    léger  ADJ    amod   adjective            adjective
# effort   NOUN   effort NOUN   obl:mod noun                 noun
# de       ADP    de     ADP    case   adposition           adposition
# mémoire  NOUN   mémoire NOUN   nmod   noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# je       PRON   je     PRON   nsubj  pronoun              pronoun
# me       PRON   me     PRON   iobj   pronoun              pronoun
# les      PRON   le     PRON   iobj   pronoun              pronoun
# suis     AUX    être   AUX    aux:tense auxiliary            auxiliary
# rappelés VERB   rappeler VERB   ROOT   verb                 verb
# tout     ADV    tout   ADV    advmod adverb               adverb
# à        ADP    à      ADP    fixed  adposition           adposition
# fait     NOUN   fait   NOUN   fixed  noun                 noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# Ainsi    ADV    ainsi  ADV    advmod adverb               adverb
# pourrais ADV    pouvoir ADV    ROOT   adverb               adverb
# -je      PRON   je     PRON   dep    pronoun              pronoun
# vous     PRON   vous   PRON   iobj   pronoun              pronoun
# réciter  VERB   réciter VERB   xcomp  verb                 verb
# Thucydide PROPN  Thucydide PROPN  obl:arg proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# Xénophon NUM    Xénophon NUM    conj   numeral              numeral
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# Plutarque PROPN  Plutarque PROPN  conj   proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# Tite     PROPN  Tite   PROPN  nmod   proper noun          proper noun
# -        PROPN  -      PROPN  nmod   proper noun          proper noun
# Live     PROPN  Live   PROPN  nmod   proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# Tacite   PROPN  Tacite PROPN  conj   proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# Strada   PROPN  Strada PROPN  nmod   proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# Jornandès PROPN  Jornandès PROPN  conj   proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# Dante    PROPN  Dante  PROPN  conj   proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# Montaigne PROPN  Montaigne PROPN  conj   proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# Shakespeare PROPN  Shakespeare PROPN  conj   proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# Spinosa  PROPN  Spinosa PROPN  conj   proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# Machiavel PROPN  Machiavel PROPN  conj   proper noun          proper noun
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# Bossuet  PROPN  Bossuet PROPN  conj   proper noun          proper noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# Je       PRON   je     PRON   nsubj  pronoun              pronoun
# ne       ADV    ne     ADV    advmod adverb               adverb
# vous     PRON   vous   PRON   iobj   pronoun              pronoun
# cite     VERB   citer  VERB   ROOT   verb                 verb
# que      SCONJ  que    SCONJ  mark   subordinating conjunction subordinating conjunction
# les      DET    le     DET    det    determiner           determiner
# plus     ADV    plus   ADV    advmod adverb               adverb
# importants ADJ    important ADJ    ccomp  adjective            adjective
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Mais   NOUN   --mai  NOUN   nsubj  noun                 noun
# vous     PRON   vous   PRON   nsubj  pronoun              pronoun
# savez    VERB   savoir VERB   ROOT   verb                 verb
# donc     ADV    donc   ADV    advmod adverb               adverb
# plusieurs DET    plusieurs DET    det    determiner           determiner
# langues  NOUN   langue NOUN   obj    noun                 noun
# ?        PUNCT  ?      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Je     NOUN   --je   NOUN   det    noun                 noun
# parle    NOUN   parle  NOUN   ROOT   noun                 noun
# cinq     NUM    cinq   NUM    nummod numeral              numeral
# langues  NOUN   langue NOUN   nmod   noun                 noun
# vivantes ADJ    vivant ADJ    amod   adjective            adjective
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# l'       DET    le     DET    det    determiner           determiner
# allemand PROPN  allemand PROPN  conj   proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# le       DET    le     DET    det    determiner           determiner
# français NOUN   français NOUN   conj   noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# l'       DET    le     DET    det    determiner           determiner
# italien  NOUN   italien NOUN   conj   noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# l'       DET    le     DET    det    determiner           determiner
# anglais  NOUN   anglais NOUN   appos  noun                 noun
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# l'       DET    le     DET    det    determiner           determiner
# espagnol NOUN   espagnol NOUN   conj   noun                 noun
# ;        PUNCT  ;      PUNCT  punct  punctuation          punctuation
# à        ADP    à      ADP    case   adposition           adposition
# l'       DET    le     DET    det    determiner           determiner
# ...
# l'       DET    le     DET    det    determiner           determiner
# espérance NOUN   espérance NOUN   obj    noun                 noun
# d'       ADP    de     ADP    mark   adposition           adposition
# augmenter VERB   augmenter VERB   xcomp  verb                 verb
# ma       DET    mon    DET    det    determiner           determiner
# provision NOUN   provision NOUN   obj    noun                 noun
# de       ADP    de     ADP    case   adposition           adposition
# plumes   NOUN   plume  NOUN   nmod   noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# mes      DET    mon    DET    det    determiner           determiner
# travaux  NOUN   travail NOUN   nsubj  noun                 noun
# historiques ADJ    historique ADJ    amod   adjective            adjective
# sont     AUX    être   AUX    cop    auxiliary            auxiliary
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# je       PRON   je     PRON   nsubj  pronoun              pronoun
# l'       PRON   le     PRON   obj    pronoun              pronoun
# avoue    NOUN   avoue  NOUN   advcl  noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# ma       DET    mon    DET    det    determiner           determiner
# plus     ADV    plus   ADV    advmod adverb               adverb
# douce    VERB   doux   VERB   conj   verb                 verb
# occupation NOUN   occupation NOUN   amod   noun                 noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# En       ADP    en     ADP    case   adposition           adposition
# descendant NOUN   descendant NOUN   obl:mod noun                 noun
# dans     ADP    dans   ADP    case   adposition           adposition
# le       DET    le     DET    det    determiner           determiner
# passé    NOUN   passé  NOUN   obl:mod noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# j'       PRON   je     PRON   nsubj  pronoun              pronoun
# oublie   VERB   oublier VERB   ROOT   verb                 verb
# le       DET    le     DET    det    determiner           determiner
# présent  NOUN   présent NOUN   obj    noun                 noun
# ;        PUNCT  ;      PUNCT  punct  punctuation          punctuation
# en       ADP    en     ADP    mark   adposition           adposition
# marchant ADJ    marchant ADJ    advcl  adjective            adjective
# libre    ADJ    libre  ADJ    amod   adjective            adjective
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# indépendant VERB   indépender VERB   conj   verb                 verb
# dans     ADP    dans   ADP    case   adposition           adposition
# l'       DET    le     DET    det    determiner           determiner
# histoire NOUN   histoire NOUN   obl:arg noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# je       PRON   je     PRON   nsubj  pronoun              pronoun
# ne       ADV    ne     ADV    advmod adverb               adverb
# me       PRON   me     PRON   expl:comp pronoun              pronoun
# souviens VERB   souvenir VERB   ROOT   verb                 verb
# plus     ADV    plus   ADV    advmod adverb               adverb
# que      SCONJ  que    SCONJ  mark   subordinating conjunction subordinating conjunction
# je       PRON   je     PRON   nsubj  pronoun              pronoun
# suis     AUX    être   AUX    cop    auxiliary            auxiliary
# prisonnier ADJ    prisonnier ADJ    ccomp  adjective            adjective
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Mais   NUM    --Mais NUM    ROOT   numeral              numeral
# de       ADP    de     ADP    det    adposition           adposition
# l'       DET    le     DET    fixed  determiner           determiner
# encre    NOUN   encre  NOUN   nmod   noun                 noun
# ?        PUNCT  ?      PUNCT  punct  punctuation          punctuation
# dit      VERB   dire   VERB   ROOT   verb                 verb
# Dantès   PROPN  Dantès PROPN  obj    proper noun          proper noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# avec     ADP    avec   ADP    case   adposition           adposition
# quoi     PRON   quoi   PRON   obl:mod pronoun              pronoun
# vous     PRON   vous   PRON   nsubj  pronoun              pronoun
# êtes     AUX    être   AUX    dep    auxiliary            auxiliary
# -vous    PRON   vous   PRON   dep    pronoun              pronoun
# fait     VERB   faire  VERB   ccomp  verb                 verb
# de       ADP    de     ADP    det    adposition           adposition
# l'       DET    le     DET    fixed  determiner           determiner
# encre    NOUN   encre  NOUN   obj    noun                 noun
# ?        PUNCT  ?      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Il     NOUN   --il   NOUN   det    noun                 noun
# y        PRON   y      PRON   iobj   pronoun              pronoun
# avait    VERB   avoir  VERB   dep    verb                 verb
# autrefois VERB   autrefois VERB   ROOT   verb                 verb
# une      DET    un     DET    det    determiner           determiner
# cheminée NOUN   cheminée NOUN   ROOT   noun                 noun
# dans     ADP    dans   ADP    case   adposition           adposition
# mon      DET    mon    DET    det    determiner           determiner
# cachot   NOUN   cachot NOUN   nmod   noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# dit      VERB   dire   VERB   conj   verb                 verb
# Faria    PROPN  Faria  PROPN  nsubj  proper noun          proper noun
# ;        PUNCT  ;      PUNCT  ROOT   punctuation          punctuation
# cette    DET    ce     DET    det    determiner           determiner
# cheminée NOUN   cheminée NOUN   nsubj:pass noun                 noun
# a        AUX    avoir  AUX    aux:tense auxiliary            auxiliary
# été      AUX    être   AUX    aux:pass auxiliary            auxiliary
# bouchée  VERB   boucher VERB   ROOT   verb                 verb
# quelque  DET    quelque DET    det    determiner           determiner
# temps    NOUN   temps  NOUN   obl:mod noun                 noun
# avant    ADP    avant  ADP    case   adposition           adposition
# mon      DET    mon    DET    det    determiner           determiner
# arrivée  NOUN   arrivée NOUN   obl:mod noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# sans     ADP    sans   ADP    case   adposition           adposition
# doute    NOUN   doute  NOUN   obl:mod noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# mais     CCONJ  mais   CCONJ  cc     coordinating conjunction coordinating conjunction
# pendant  ADP    pendant ADP    case   adposition           adposition
# de       DET    de     DET    det    determiner           determiner
# longues  ADJ    long   ADJ    amod   adjective            adjective
# années   NOUN   année  NOUN   nsubj  noun                 noun
# on       PRON   on     PRON   nsubj  pronoun              pronoun
# y        PRON   y      PRON   expl:comp pronoun              pronoun
# avait    VERB   avoir  VERB   aux:tense verb                 verb
# fait     VERB   faire  VERB   advcl  verb                 verb
# du       ADP    de     ADP    case   adposition           adposition
# feu      NOUN   feu    NOUN   obj    noun                 noun
# :        PUNCT  :      PUNCT  punct  punctuation          punctuation
# tout     ADJ    tout   ADJ    amod   adjective            adjective
# l'       DET    le     DET    det    determiner           determiner
# intérieur NOUN   intérieur NOUN   obl:mod noun                 noun
# en       PRON   en     PRON   iobj   pronoun              pronoun
# est      AUX    être   AUX    cop    auxiliary            auxiliary
# donc     ADV    donc   ADV    advmod adverb               adverb
# tapissé  VERB   tapisser VERB   acl    verb                 verb
# de       ADP    de     ADP    case   adposition           adposition
# suie     NOUN   suie   NOUN   obl:arg noun                 noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# Je       PRON   je     PRON   nsubj  pronoun              pronoun
# fais     VERB   faire  VERB   advcl  verb                 verb
# dissoudre VERB   dissoudre VERB   xcomp  verb                 verb
# cette    DET    ce     DET    det    determiner           determiner
# suie     NOUN   suie   NOUN   obj    noun                 noun
# dans     ADP    dans   ADP    case   adposition           adposition
# une      DET    un     DET    det    determiner           determiner
# portion  NOUN   portion NOUN   obl:arg noun                 noun
# du       ADP    de     ADP    case   adposition           adposition
# vin      NOUN   vin    NOUN   nmod   noun                 noun
# qu'      SCONJ  que    SCONJ  obj    subordinating conjunction subordinating conjunction
# on       PRON   on     PRON   nsubj  pronoun              pronoun
# me       PRON   me     PRON   iobj   pronoun              pronoun
# donne    VERB   donne  VERB   ccomp  verb                 verb
# tous     ADJ    tout   ADJ    amod   adjective            adjective
# les      DET    le     DET    det    determiner           determiner
# dimanches NOUN   dimanche NOUN   obj    noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# cela     PRON   celer  PRON   nsubj  pronoun              pronoun
# me       PRON   me     PRON   iobj   pronoun              pronoun
# fournit  VERB   fournir VERB   ROOT   verb                 verb
# de       ADP    de     ADP    case   adposition           adposition
# l'       DET    le     DET    det    determiner           determiner
# encre    NOUN   encre  NOUN   obl:arg noun                 noun
# excellente ADJ    excellent ADJ    amod   adjective            adjective
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# Pour     ADP    pour   ADP    case   adposition           adposition
# les      DET    le     DET    det    determiner           determiner
# notes    NOUN   note   NOUN   obl:mod noun                 noun
# particulières ADJ    particulier ADJ    amod   adjective            adjective
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# qui      PRON   qui    PRON   nsubj  pronoun              pronoun
# ont      VERB   avoir  VERB   conj   verb                 verb
# besoin   NOUN   besoin NOUN   obj    noun                 noun
# d'       ADP    de     ADP    mark   adposition           adposition
# attirer  VERB   attirer VERB   xcomp  verb                 verb
# les      DET    le     DET    det    determiner           determiner
# yeux     NOUN   oeil   NOUN   obj    noun                 noun
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# je       PRON   je     PRON   nsubj  pronoun              pronoun
# me       PRON   me     PRON   iobj   pronoun              pronoun
# pique    VERB   pique  VERB   ROOT   verb                 verb
# les      DET    le     DET    det    determiner           determiner
# doigts   NOUN   doigt  NOUN   obj    noun                 noun
# et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# j'       PRON   je     PRON   nsubj  pronoun              pronoun
# écris    VERB   écrire VERB   conj   verb                 verb
# avec     ADP    avec   ADP    case   adposition           adposition
# mon      DET    mon    DET    det    determiner           determiner
# sang     NOUN   sang   NOUN   obl:agent noun                 noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Et     NOUN   --et   NOUN   obj    noun                 noun
# quand    SCONJ  quand  SCONJ  mark   subordinating conjunction subordinating conjunction
# pourrai  PROPN  pouvoir PROPN  nsubj  proper noun          proper noun
# -je      PRON   je     PRON   nsubj  pronoun              pronoun
# voir     VERB   voir   VERB   advcl  verb                 verb
# tout     ADV    tout   ADV    amod   adverb               adverb
# cela     PRON   celer  PRON   obj    pronoun              pronoun
# ?        PUNCT  ?      PUNCT  punct  punctuation          punctuation
# demanda  NOUN   demanda NOUN   ROOT   noun                 noun
# Dantès   NOUN   dantè  NOUN   nmod   noun                 noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Quand  ADJ    --quand ADJ    nsubj  adjective            adjective
# vous     PRON   vous   PRON   nsubj  pronoun              pronoun
# voudrez  VERB   vouloir VERB   ROOT   verb                 verb
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# répondit NOUN   répondit NOUN   obj    noun                 noun
# Faria    ADJ    faria  ADJ    amod   adjective            adjective
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Oh     NOUN   --oh   NOUN   obj    noun                 noun
# !        PUNCT  !      PUNCT  punct  punctuation          punctuation
# tout     ADV    tout   ADV    ROOT   adverb               adverb
# de       ADP    de     ADP    case   adposition           adposition
# suite    NOUN   suite  NOUN   obl:arg noun                 noun
# !        PUNCT  !      PUNCT  punct  punctuation          punctuation
# s'       PRON   se     PRON   expl:comp pronoun              pronoun
# écria    VERB   écrier VERB   ROOT   verb                 verb
# le       DET    le     DET    det    determiner           determiner
# jeune    ADJ    jeune  ADJ    amod   adjective            adjective
# homme    NOUN   homme  NOUN   obj    noun                 noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# --Suivez PRON   --suivez PRON   ROOT   pronoun              pronoun
# -moi     PRON   moi    PRON   dep    pronoun              pronoun
# donc     ADV    donc   ADV    advmod adverb               adverb
# »        PUNCT  »      PUNCT  punct  punctuation          punctuation
# ,        PUNCT  ,      PUNCT  punct  punctuation          punctuation
# dit      VERB   dire   VERB   parataxis verb                 verb
# l'       DET    le     DET    det    determiner           determiner
# abbé     NOUN   abbé   NOUN   obj    noun                 noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space
# Et       CCONJ  et     CCONJ  cc     coordinating conjunction coordinating conjunction
# il       PRON   il     PRON   nsubj  pronoun              pronoun
# rentra   VERB   rentrer VERB   conj   verb                 verb
# dans     ADP    dans   ADP    case   adposition           adposition
# le       DET    le     DET    det    determiner           determiner
# corridor NOUN   corridor NOUN   obl:arg noun                 noun
# souterrain ADJ    souterrain ADJ    amod   adjective            adjective
# où       PRON   où     PRON   iobj   pronoun              pronoun
# il       PRON   il     PRON   nsubj  pronoun              pronoun
# disparut ADJ    disparut ADJ    acl:relcl adjective            adjective
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
# Dantès   NOUN   dantè  NOUN   ROOT   noun                 noun
# le       DET    le     DET    det    determiner           determiner
# suivit   NOUN   suivit NOUN   nmod   noun                 noun
# .        PUNCT  .      PUNCT  punct  punctuation          punctuation
#          SPACE         SPACE  dep    space                space

# %%
# creating csv file to store spacy output
# filename = "spacy_output.csv"
# header = ["TOKEN", "POS","LEMMA"]

#with open(filename, "w", newline="", encoding="UTF-8") as csvfile:
    #writer = csv.writer(csvfile)
    #writer.writerow(header)

    #for token in doc:
        #row = [token.text, token.pos_,token.lemma_]
        #writer.writerow(row)

# %% [markdown]
# ### Évaluation de l'annotateur *Spacy* :
# #### Rappel, précision, et f-score
# Afin de manipuler les résultats obtenus avec Spacy (écrits dans un fichier .csv), on utilise le module *pandas*, importé précédemment.
# On évalue ici deux annotations :
# - *POS tagging*
# - *lemma*
#
# Ainsi, on va avoir deux matrices de confusions, une par annotation à évaluer.

# %%
# load csv files as dataframes
df_spacy = pd.read_csv('data/spacy_output.csv', error_bad_lines=False, sep = ',')
df_gold = pd.read_csv('data/spacy_output_gold.csv', error_bad_lines=False, sep = ';')
# Out:
# /tmp/ipykernel_26831/1734072599.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_spacy = pd.read_csv('data/spacy_output.csv', error_bad_lines=False, sep = ',')
# /tmp/ipykernel_26831/1734072599.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_gold = pd.read_csv('data/spacy_output_gold.csv', error_bad_lines=False, sep = ';')

# %%
df_gold.head(8)
# Out:
#       TOKEN    POS      LEMMA
# 0    Dantès    NUM     Dantès
# 1     resta   VERB     rester
# 2  confondu    ADJ  confondre
# 3         :  PUNCT          :
# 4        c'   PRON         ce
# 5     était    AUX       être
# 6         ,  PUNCT          ,
# 7        en    ADP         en

# %%
token = df_spacy['TOKEN']
pos = df_spacy['POS']
lemma = df_spacy['LEMMA']
token_gold = df_gold['TOKEN']
pos_gold = df_gold['POS']
lemma_gold = df_gold['LEMMA']

# %%
# confusion matrix
vp_pos, fp_pos, fn_pos = conf_matrix(token, token_gold, "POS", pos, pos_gold)
vp_lemma, fp_lemma, fn_lemma = conf_matrix(token, token_gold, "lemma", lemma, lemma_gold)
vp_token, fp_token, fn_token = conf_matrix_token(token, token_gold)
# Out:
# Token : ﻿Dantès | Token Gold : Dantès | POS : PUNCT | POS Gold : NUM
# Token : resta | Token Gold : resta | POS : PRON | POS Gold : VERB
# Token : confondu | Token Gold : confondu | POS : VERB | POS Gold : ADJ
# Token : « | Token Gold : « | POS : NOUN | POS Gold : PROPN
# Token : Faria | Token Gold : Faria | POS : ADJ | POS Gold : PROPN
# Token : douze | Token Gold : douze | POS : VERB | POS Gold : NUM
# Token : ans | Token Gold : ans | POS : ADJ | POS Gold : NOUN
# Token : sont | Token Gold : sont | POS : AUX | POS Gold : VERB
# Token : Vincennes | Token Gold : Vincennes | POS : NOUN | POS Gold : PROPN
# Token : Dubuquoi | Token Gold : Dubuquoi | POS : ADV | POS Gold : ADJ
# Token : Fort-l'Évêque | Token Gold : Fort-l'Évêque | POS : NOUN | POS Gold : PROPN
# Token : celles | Token Gold : celles | POS : ADJ | POS Gold : PRON
# Token : que | Token Gold : que | POS : SCONJ | POS Gold : PRON
# Token : croyez | Token Gold : croyez | POS : NOUN | POS Gold : VERB
# Token : profitons | Token Gold : profitons | POS : NOUN | POS Gold : VERB
# Token : soupirant | Token Gold : soupirant | POS : NOUN | POS Gold : VERB
# Token : --Puis | Token Gold : --Puis | POS : PRON | POS Gold : ADV
# Token : point | Token Gold : point | POS : VERB | POS Gold : ADV
# Token : faisiez | Token Gold : faisiez | POS : ADV | POS Gold : VERB
# Token : --J' | Token Gold : --J' | POS : NUM | POS Gold : PRON
# Token : écrivais | Token Gold : écrivais | POS : NOUN | POS Gold : VERB
# Token : étudiais | Token Gold : étudiais | POS : PROPN | POS Gold : VERB
# Token : --On | Token Gold : --On | POS : DET | POS Gold : PRON
# Token : --Non | Token Gold : --Non | POS : PRON | POS Gold : ADV
# Token : en | Token Gold : en | POS : VERB | POS Gold : PRON
# Token : fais | Token Gold : fais | POS : NOUN | POS Gold : ADJ
# Token : écria | Token Gold : écria | POS : NOUN | POS Gold : VERB
# Token : Dantès | Token Gold : Dantès | POS : PROPN | POS Gold : NOUN
# Token : cet | Token Gold : cet | POS : DET | POS Gold : PRON
# Token : ce | Token Gold : ce | POS : DET | POS Gold : PRON
# Token : « | Token Gold : « | POS : PROPN | POS Gold : PUNCT
# Token : guère | Token Gold : guère | POS : ADV | POS Gold : ADJ
# Token : est | Token Gold : est | POS : AUX | POS Gold : VERB
# Token : _ | Token Gold : _ | POS : NOUN | POS Gold : ADJ
# Token : Italie_. | Token Gold : Italie_. | POS : PROPN | POS Gold : NOUN
# Token : in | Token Gold : in | POS : PROPN | POS Gold : ADJ
# Token : - | Token Gold : - | POS : PROPN | POS Gold : PUNCT
# Token : quarto | Token Gold : quarto | POS : PROPN | POS Gold : ADJ
# Token : --Et | Token Gold : --Et | POS : NOUN | POS Gold : CCONJ
# Token : --Sur | Token Gold : --Sur | POS : NOUN | POS Gold : ADP
# Token : uni | Token Gold : uni | POS : PROPN | POS Gold : ADJ
# Token : êtes | Token Gold : êtes | POS : AUX | POS Gold : VERB
# Token : chimiste | Token Gold : chimiste | POS : ADJ | POS Gold : NOUN
# Token : --Un | Token Gold : --Un | POS : ADV | POS Gold : DET
# Token : Lavoisier | Token Gold : Lavoisier | POS : PROPN | POS Gold : NOUN
# Token : suis | Token Gold : suis | POS : AUX | POS Gold : VERB
# Token : --Mais | Token Gold : --Mais | POS : NUM | POS Gold : CCONJ
# Token : --À | Token Gold : --À | POS : NOUN | POS Gold : ADP
# Token : mille | Token Gold : mille | POS : DET | POS Gold : NUM
# Token : les | Token Gold : les | POS : PRON | POS Gold : DET
# Token : choisis | Token Gold : choisis | POS : ADJ | POS Gold : VERB
# Token : a | Token Gold : a | POS : AUX | POS Gold : VERB
# Token : sinon | Token Gold : sinon | POS : ADV | POS Gold : VERB
# Token : tout | Token Gold : tout | POS : ADJ | POS Gold : PRON
# Token : savais | Token Gold : savais | POS : ADJ | POS Gold : VERB
# Token : pourrais | Token Gold : pourrais | POS : ADV | POS Gold : VERB
# Token : Thucydide | Token Gold : Thucydide | POS : PROPN | POS Gold : NOUN
# Token : Xénophon | Token Gold : Xénophon | POS : NUM | POS Gold : PROPN
# Token : --Mais | Token Gold : --Mais | POS : NOUN | POS Gold : CCONJ
# Token : plusieurs | Token Gold : plusieurs | POS : DET | POS Gold : ADJ
# Token : --Je | Token Gold : --Je | POS : NOUN | POS Gold : PRON
# Token : parle | Token Gold : parle | POS : NOUN | POS Gold : VERB
# Token : allemand | Token Gold : allemand | POS : PROPN | POS Gold : NOUN
# Token : grec | Token Gold : grec | POS : PROPN | POS Gold : NOUN
# Token : le | Token Gold : le | POS : DET | POS Gold : PRON
# Token : mal | Token Gold : mal | POS : NOUN | POS Gold : ADV
# Token : l' | Token Gold : l' | POS : DET | POS Gold : PRON
# Token : étudie | Token Gold : étudie | POS : NOUN | POS Gold : VERB
# Token : ce | Token Gold : ce | POS : DET | POS Gold : PRON
# Token : --Vous | Token Gold : --Vous | POS : PRON | POS Gold : NOUN
# Token : l' | Token Gold : l' | POS : PRON | POS Gold : DET
# Token : étudiez | Token Gold : étudiez | POS : NOUN | POS Gold : VERB
# Token : dit | Token Gold : dit | POS : NOUN | POS Gold : VERB
# Token : ai | Token Gold : ai | POS : ADJ | POS Gold : AUX
# Token : arrangés | Token Gold : arrangés | POS : ADJ | POS Gold : VERB
# Token : combinés | Token Gold : combinés | POS : NOUN | POS Gold : VERB
# Token : tournés | Token Gold : tournés | POS : NOUN | POS Gold : VERB
# Token : mille | Token Gold : mille | POS : NOUN | POS Gold : NUM
# Token : serai | Token Gold : serai | POS : AUX | POS Gold : VERB
# Token : éloquent | Token Gold : éloquent | POS : ADV | POS Gold : ADJ
# Token : cet | Token Gold : cet | POS : DET | POS Gold : PRON
# Token : étrange | Token Gold : étrange | POS : NOUN | POS Gold : ADJ
# Token : « | Token Gold : « | POS : NOUN | POS Gold : PROPN
# Token : de | Token Gold : de | POS : DET | POS Gold : PREP
# Token : écrire | Token Gold : écrire | POS : ADJ | POS Gold : VERB
# Token : volumineux | Token Gold : volumineux | POS : NOUN | POS Gold : ADJ
# Token : excellentes | Token Gold : excellentes | POS : NOUN | POS Gold : ADJ
# Token : ces | Token Gold : ces | POS : DET | POS Gold : PRON
# Token : vois | Token Gold : vois | POS : ADJ | POS Gold : SCONJ
# Token : descendant | Token Gold : descendant | POS : NOUN | POS Gold : VERB
# Token : marchant | Token Gold : marchant | POS : ADJ | POS Gold : VERB
# Token : --Mais | Token Gold : --Mais | POS : NUM | POS Gold : CCONJ
# Token : autrefois | Token Gold : autrefois | POS : VERB | POS Gold : ADV
# Token : Faria | Token Gold : Faria | POS : PROPN | POS Gold : NOUN
# Token : cette | Token Gold : cette | POS : DET | POS Gold : PRON
# Token : avait | Token Gold : avait | POS : VERB | POS Gold : AUX
# Token : cette | Token Gold : cette | POS : DET | POS Gold : PRON
# Token : qu' | Token Gold : qu' | POS : SCONJ | POS Gold : PRON
# Token : --Et | Token Gold : --Et | POS : NOUN | POS Gold : DET
# Token : pourrai | Token Gold : pourrai | POS : PROPN | POS Gold : VERB
# Token : tout | Token Gold : tout | POS : ADV | POS Gold : ADJ
# Token : demanda | Token Gold : demanda | POS : NOUN | POS Gold : VERB
# Token : Dantès | Token Gold : Dantès | POS : NOUN | POS Gold : PROPN
# Token : --Quand | Token Gold : --Quand | POS : ADJ | POS Gold : ADV
# Token : répondit | Token Gold : répondit | POS : NOUN | POS Gold : VERB
# Token : --Oh | Token Gold : --Oh | POS : NOUN | POS Gold : INT
# Token : --Suivez | Token Gold : --Suivez | POS : PRON | POS Gold : VERB
# Token : disparut | Token Gold : disparut | POS : ADJ | POS Gold : VERB
# Token : ﻿Dantès | Token Gold : Dantès | lemma : ﻿dantès | lemma Gold : Dantès
# Token : resta | Token Gold : resta | lemma : rester | lemma Gold : rester
# Token : confondu | Token Gold : confondu | lemma : confondre | lemma Gold : confondre
# Token : « | Token Gold : « | lemma : « | lemma Gold : «
# Token : Faria | Token Gold : Faria | lemma : faria | lemma Gold : Faria
# Token : douze | Token Gold : douze | lemma : douze | lemma Gold : douze
# Token : ans | Token Gold : ans | lemma : an | lemma Gold : an
# Token : sont | Token Gold : sont | lemma : être | lemma Gold : être
# Token : Vincennes | Token Gold : Vincennes | lemma : vincenne | lemma Gold : Vincennes
# Token : Dubuquoi | Token Gold : Dubuquoi | lemma : dubuquoi | lemma Gold : Dubuquoi
# Token : Fort-l'Évêque | Token Gold : Fort-l'Évêque | lemma : fort-l'évêque | lemma Gold : Fort-l'Évêque
# Token : celles | Token Gold : celles | lemma : celle | lemma Gold : celui
# Token : que | Token Gold : que | lemma : que | lemma Gold : que
# Token : croyez | Token Gold : croyez | lemma : croyez | lemma Gold : croire
# Token : profitons | Token Gold : profitons | lemma : profiton | lemma Gold : profiter
# Token : soupirant | Token Gold : soupirant | lemma : soupirant | lemma Gold : soupirer
# Token : --Puis | Token Gold : --Puis | lemma : --puis | lemma Gold : --puis
# Token : point | Token Gold : point | lemma : poindre | lemma Gold : point
# Token : faisiez | Token Gold : faisiez | lemma : faire | lemma Gold : faire
# Token : --J' | Token Gold : --J' | lemma : --J' | lemma Gold : --j'
# Token : écrivais | Token Gold : écrivais | lemma : écrivai | lemma Gold : écrivai
# Token : étudiais | Token Gold : étudiais | lemma : étudier | lemma Gold : étudier
# Token : --On | Token Gold : --On | lemma : --on | lemma Gold : --on
# Token : --Non | Token Gold : --Non | lemma : --non | lemma Gold : --non
# Token : en | Token Gold : en | lemma : en | lemma Gold : en
# Token : fais | Token Gold : fais | lemma : fai | lemma Gold : fai
# Token : écria | Token Gold : écria | lemma : écria | lemma Gold : écrier
# Token : Dantès | Token Gold : Dantès | lemma : Dantès | lemma Gold : Dantès
# Token : cet | Token Gold : cet | lemma : ce | lemma Gold : ce
# Token : ce | Token Gold : ce | lemma : ce | lemma Gold : ce
# Token : « | Token Gold : « | lemma : « | lemma Gold : «
# Token : guère | Token Gold : guère | lemma : guère | lemma Gold : guère
# Token : est | Token Gold : est | lemma : être | lemma Gold : être
# Token : _ | Token Gold : _ | lemma : _ | lemma Gold : _
# Token : Italie_. | Token Gold : Italie_. | lemma : Italie_. | lemma Gold : italie_.
# Token : in | Token Gold : in | lemma : in | lemma Gold : in
# Token : - | Token Gold : - | lemma : - | lemma Gold : -
# Token : quarto | Token Gold : quarto | lemma : quarto | lemma Gold : quarto
# Token : --Et | Token Gold : --Et | lemma : --et | lemma Gold : --et
# Token : --Sur | Token Gold : --Sur | lemma : --sur | lemma Gold : --sur
# Token : uni | Token Gold : uni | lemma : uni | lemma Gold : uni
# Token : êtes | Token Gold : êtes | lemma : être | lemma Gold : être
# Token : chimiste | Token Gold : chimiste | lemma : chimist | lemma Gold : chimiste
# Token : --Un | Token Gold : --Un | lemma : --un | lemma Gold : --un
# Token : Lavoisier | Token Gold : Lavoisier | lemma : Lavoisier | lemma Gold : lavoisier
# Token : suis | Token Gold : suis | lemma : être | lemma Gold : être
# Token : --Mais | Token Gold : --Mais | lemma : --Mais | lemma Gold : —mais
# Token : --À | Token Gold : --À | lemma : --à | lemma Gold : --À
# Token : mille | Token Gold : mille | lemma : mille | lemma Gold : mille
# Token : les | Token Gold : les | lemma : le | lemma Gold : le
# Token : choisis | Token Gold : choisis | lemma : choisir | lemma Gold : choisir
# Token : a | Token Gold : a | lemma : avoir | lemma Gold : avoir
# Token : sinon | Token Gold : sinon | lemma : sinon | lemma Gold : sinon
# Token : tout | Token Gold : tout | lemma : tout | lemma Gold : tout
# Token : savais | Token Gold : savais | lemma : savai | lemma Gold : savoir
# Token : pourrais | Token Gold : pourrais | lemma : pouvoir | lemma Gold : pouvoir
# Token : Thucydide | Token Gold : Thucydide | lemma : Thucydide | lemma Gold : thucydide
# Token : Xénophon | Token Gold : Xénophon | lemma : Xénophon | lemma Gold : Xénophon
# Token : --Mais | Token Gold : --Mais | lemma : --mai | lemma Gold : —mais
# Token : plusieurs | Token Gold : plusieurs | lemma : plusieurs | lemma Gold : plusieurs
# Token : --Je | Token Gold : --Je | lemma : --je | lemma Gold : --Je
# Token : parle | Token Gold : parle | lemma : parle | lemma Gold : parler
# Token : allemand | Token Gold : allemand | lemma : allemand | lemma Gold : allemand
# Token : grec | Token Gold : grec | lemma : grec | lemma Gold : grec
# Token : le | Token Gold : le | lemma : le | lemma Gold : le
# Token : mal | Token Gold : mal | lemma : mal | lemma Gold : mal
# Token : l' | Token Gold : l' | lemma : le | lemma Gold : le
# Token : étudie | Token Gold : étudie | lemma : étudie | lemma Gold : étudier
# Token : ce | Token Gold : ce | lemma : ce | lemma Gold : ce
# Token : --Vous | Token Gold : --Vous | lemma : --vous | lemma Gold : —vous
# Token : l' | Token Gold : l' | lemma : le | lemma Gold : le
# Token : étudiez | Token Gold : étudiez | lemma : étudiez | lemma Gold : étudier
# Token : dit | Token Gold : dit | lemma : dit | lemma Gold : dire
# Token : ai | Token Gold : ai | lemma : ai | lemma Gold : avoir
# Token : arrangés | Token Gold : arrangés | lemma : arranger | lemma Gold : arranger
# Token : combinés | Token Gold : combinés | lemma : combiné | lemma Gold : combiner
# Token : tournés | Token Gold : tournés | lemma : tourné | lemma Gold : tourner
# Token : mille | Token Gold : mille | lemma : mille | lemma Gold : mille
# Token : serai | Token Gold : serai | lemma : être | lemma Gold : être
# Token : éloquent | Token Gold : éloquent | lemma : éloquent | lemma Gold : éloquent
# Token : cet | Token Gold : cet | lemma : ce | lemma Gold : ce
# Token : étrange | Token Gold : étrange | lemma : étrange | lemma Gold : étrange
# Token : « | Token Gold : « | lemma : « | lemma Gold : «
# Token : de | Token Gold : de | lemma : de | lemma Gold : de
# Token : écrire | Token Gold : écrire | lemma : écrir | lemma Gold : écrire
# Token : volumineux | Token Gold : volumineux | lemma : volumineu | lemma Gold : volumineux
# Token : excellentes | Token Gold : excellentes | lemma : excellente | lemma Gold : excellente
# Token : ces | Token Gold : ces | lemma : ce | lemma Gold : ce
# Token : vois | Token Gold : vois | lemma : voi | lemma Gold : vois
# Token : descendant | Token Gold : descendant | lemma : descendant | lemma Gold : descendre
# Token : marchant | Token Gold : marchant | lemma : marchant | lemma Gold : marcher
# Token : --Mais | Token Gold : --Mais | lemma : --Mais | lemma Gold : —mais
# Token : autrefois | Token Gold : autrefois | lemma : autrefois | lemma Gold : autrefois
# Token : Faria | Token Gold : Faria | lemma : Faria | lemma Gold : faria
# Token : cette | Token Gold : cette | lemma : ce | lemma Gold : ce
# Token : avait | Token Gold : avait | lemma : avoir | lemma Gold : avoir
# Token : cette | Token Gold : cette | lemma : ce | lemma Gold : ce
# Token : qu' | Token Gold : qu' | lemma : que | lemma Gold : que
# Token : --Et | Token Gold : --Et | lemma : --et | lemma Gold : --et
# Token : pourrai | Token Gold : pourrai | lemma : pouvoir | lemma Gold : pouvoir
# Token : tout | Token Gold : tout | lemma : tout | lemma Gold : tout
# Token : demanda | Token Gold : demanda | lemma : demanda | lemma Gold : demander
# Token : Dantès | Token Gold : Dantès | lemma : dantè | lemma Gold : Dantès
# Token : --Quand | Token Gold : --Quand | lemma : --quand | lemma Gold : --Quand
# Token : répondit | Token Gold : répondit | lemma : répondit | lemma Gold : répondre
# Token : --Oh | Token Gold : --Oh | lemma : --oh | lemma Gold : --Oh
# Token : --Suivez | Token Gold : --Suivez | lemma : --suivez | lemma Gold : —suivre
# Token : disparut | Token Gold : disparut | lemma : disparut | lemma Gold : disparaître
# Token : ﻿Dantès | Token Gold : Dantès

# %%
print(vp_pos, fn_pos, fp_pos)
# Out:
# 1078 0 108

# %%
p_pos, r_pos, fscore_pos = p_r_fscore(vp_pos, fp_pos, fn_pos)
p_lemma, r_lemma, fscore_lemma = p_r_fscore(vp_lemma, fp_lemma, fn_lemma)
p_token, r_token, fscore_token = p_r_fscore(vp_token, fp_token, fn_token)

print(f'Pour annotation POS : P = {round(p_pos,3)} | R = {round(r_pos,3)} | f-score = {round(fscore_pos,3)}')
print(f'Pour annotation lemma : P = {round(p_lemma,3)} | R = {round(r_lemma,3)} | f-score = {round(fscore_lemma,3)}')
print(f'Pour tokenisation : P = {round(p_token,3)} | R = {round(r_token,3)} | f-score = {round(fscore_token,3)}')
# Out:
# Pour annotation POS : P = 0.909 | R = 1.0 | f-score = 0.952
# Pour annotation lemma : P = 0.909 | R = 1.0 | f-score = 0.952
# Pour tokenisation : P = 0.999 | R = 1.0 | f-score = 1.0

# %% [markdown]
# # TREETAGGER

# %%
# data importer
df_treetagger = pd.read_csv('data/treetagger_output.csv', error_bad_lines=False, sep = ';')
df_gold = pd.read_csv('data/treetagger_output_gold.csv', error_bad_lines=False, sep = ';')

# récupération des données de chaque colonne par le biais de l'affectation
token = df_treetagger['TOKEN']
pos = df_treetagger['POS']
lemma = df_treetagger['LEMMA']
token_gold = df_gold['TOKEN_GOLD']
pos_gold = df_gold['POS_GOLD']
lemma_gold = df_gold['LEMMA_GOLD']
# Out:
# /tmp/ipykernel_26831/1327330320.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_treetagger = pd.read_csv('data/treetagger_output.csv', error_bad_lines=False, sep = ';')
# /tmp/ipykernel_26831/1327330320.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df_gold = pd.read_csv('data/treetagger_output_gold.csv', error_bad_lines=False, sep = ';')

# %%
vp_token, fp_token, fn_token = conf_matrix_token(token, token_gold)
# Out:
# Token : --J'écrivais | Token Gold : --J'
# Token : nan | Token Gold : écrivais
# Token : - | Token Gold : nan
# Token : dit-il | Token Gold : dit
# Token : nan | Token Gold : -il
# Token : quoiqu'il | Token Gold : Quoique
# Token : nan | Token Gold : Il
# Token : dit-il | Token Gold : dit
# Token : nan | Token Gold : -il

# %%
vp_pos, fp_pos, fn_pos = conf_matrix(token, token_gold, "POS", pos, pos_gold)
# Out:
# Token : des | Token Gold : des | POS : PRP:det | POS Gold : DET:ART
# Token : autres | Token Gold : autres | POS : ADJ | POS Gold : PRO:IND
# Token : Faria | Token Gold : Faria | POS : NAM | POS Gold : NOM
# Token : que | Token Gold : que | POS : PRO:REL | POS Gold : KON
# Token : toutes | Token Gold : toutes | POS : PRO:IND | POS Gold : ADJ
# Token : que | Token Gold : que | POS : KON | POS Gold : ADV
# Token : -Vous | Token Gold : -Vous | POS : ADJ | POS Gold : PRO:PER
# Token : Dantès | Token Gold : Dantès | POS : NAM | POS Gold : NOM
# Token : soupirant | Token Gold : soupirant | POS : NOM | POS Gold : VER:ppre
# Token : tous | Token Gold : tous | POS : PRO:IND | POS Gold : ADJ
# Token : --Puis | Token Gold : --Puis | POS : ADJ | POS Gold : ADV
# Token : qu' | Token Gold : qu' | POS : KON | POS Gold : ADV
# Token : --Que | Token Gold : --Que | POS : ADJ | POS Gold : PRO
# Token : --J'écrivais | Token Gold : --J' | POS : VER:impf | POS Gold : PRO:PER
# Token : nan | Token Gold : écrivais | POS : nan | POS Gold : VER:impf
# Token : -On | Token Gold : -On | POS : ADJ | POS Gold : PRO:PER
# Token : --Non | Token Gold : --Non | POS : ADJ | POS Gold : ADV
# Token : - | Token Gold : nan | POS : PUN | POS Gold : nan
# Token : --Vous | Token Gold : --Vous | POS : ADJ | POS Gold : PRO:PER
# Token : Dantès | Token Gold : Dantès | POS : NAM | POS Gold : NOM
# Token : --Oui | Token Gold : --Oui | POS : ADJ | POS Gold : ADV
# Token : Dantès | Token Gold : Dantès | POS : NAM | POS Gold : NOM
# Token : Faria | Token Gold : Faria | POS : NAM | POS Gold : NOM
# Token : dit-il | Token Gold : dit | POS : NOM | POS Gold : VER:pres
# Token : nan | Token Gold : -il | POS : nan | POS Gold : PRO:PER
# Token : toute | Token Gold : toute | POS : PRO:IND | POS Gold : ADJ
# Token : que | Token Gold : que | POS : KON | POS Gold : PRO:REL
# Token : Italie_ | Token Gold : Italie_ | POS : NOM | POS Gold : NAM
# Token : --Et | Token Gold : --Et | POS : ADJ | POS Gold : KON
# Token : --Sur | Token Gold : --Sur | POS : NOM | POS Gold : PRP
# Token : -Vous | Token Gold : -Vous | POS : ADJ | POS Gold : PRO:REL
# Token : --Un | Token Gold : --Un | POS : NOM | POS Gold : DET:ART
# Token : --Mais | Token Gold : --Mais | POS : ADJ | POS Gold : KON
# Token : des | Token Gold : des | POS : PRP:det | POS Gold : DET:ART
# Token : des | Token Gold : des | POS : PRP:det | POS Gold : DET:ART
# Token : --À | Token Gold : --À | POS : ABR | POS Gold : PRP
# Token : les | Token Gold : les | POS : DET:ART | POS Gold : PRO:PER
# Token : lire | Token Gold : lire | POS : NOM | POS Gold : VER:infi
# Token : cinquante | Token Gold : cinquante | POS : ADJ | POS Gold : NUM
# Token : cinquante | Token Gold : cinquante | POS : ADJ | POS Gold : NUM
# Token : que | Token Gold : que | POS : PRO:REL | POS Gold : KON
# Token : --Mais | Token Gold : --Mais | POS : VER:impf | POS Gold : KON
# Token : plusieurs | Token Gold : plusieurs | POS : PRO:IND | POS Gold : ADJ
# Token : -Je | Token Gold : -Je | POS : ADJ | POS Gold : PRO:PER
# Token : français | Token Gold : français | POS : ADJ | POS Gold : NOM
# Token : italien | Token Gold : italien | POS : ADJ | POS Gold : NOM
# Token : anglais | Token Gold : anglais | POS : ADJ | POS Gold : NOM
# Token : espagnol | Token Gold : espagnol | POS : ADJ | POS Gold : NOM
# Token : -Vous | Token Gold : -Vous | POS : ADJ | POS Gold : PRO:PER
# Token : Dantès | Token Gold : Dantès | POS : NAM | POS Gold : NOM
# Token : --Oui | Token Gold : --Oui | POS : ADJ | POS Gold : ADV
# Token : qu' | Token Gold : qu' | POS : PRO:REL | POS Gold : KON
# Token : tout | Token Gold : tout | POS : ADV | POS Gold : ADJ
# Token : quoiqu'il | Token Gold : Quoique | POS : ADJ | POS Gold : KON
# Token : nan | Token Gold : Il | POS : nan | POS Gold : PRO:PER
# Token : Edmond | Token Gold : Edmond | POS : NAM | POS Gold : NOM
# Token : l' | Token Gold : l' | POS : PRO:PER | POS Gold : DET:ART
# Token : dit-il | Token Gold : dit | POS : NOM | POS Gold : VER:pres
# Token : nan | Token Gold : -il | POS : nan | POS Gold : PRO:PER
# Token : quoi | Token Gold : quoi | POS : PRO:REL | POS Gold : PRO
# Token : -Je | Token Gold : -Je | POS : ADJ | POS Gold : PRO:PER
# Token : l' | Token Gold : l' | POS : PRO:PER | POS Gold : DET:ART
# Token : Aussi | Token Gold : Aussi | POS : ADV | POS Gold : KON
# Token : descendant | Token Gold : descendant | POS : NOM | POS Gold : VER:ppre
# Token : présent | Token Gold : présent | POS : ADJ | POS Gold : NOM
# Token : --Mais | Token Gold : --Mais | POS : ADJ | POS Gold : KON
# Token : Dantès | Token Gold : Dantès | POS : NAM | POS Gold : NOM
# Token : --Il | Token Gold : --Il | POS : ADJ | POS Gold : PRO:PER
# Token : Faria | Token Gold : Faria | POS : NAM | POS Gold : NOM
# Token : quelque | Token Gold : quelque | POS : PRO:IND | POS Gold : DET:ART
# Token : tous | Token Gold : tous | POS : PRO:IND | POS Gold : ADJ
# Token : --Et | Token Gold : --Et | POS : ADJ | POS Gold : KON
# Token : tout | Token Gold : tout | POS : ADV | POS Gold : ADJ
# Token : Dantès | Token Gold : Dantès | POS : NAM | POS Gold : NOM
# Token : --Quand | Token Gold : --Quand | POS : ADJ | POS Gold : ADV
# Token : Faria | Token Gold : Faria | POS : NAM | POS Gold : NOM
# Token : --Oh | Token Gold : --Oh | POS : ADJ | POS Gold : INT
# Token : Dantès | Token Gold : Dantès | POS : NAM | POS Gold : NOM

# %%
vp_lemma, fp_lemma, fn_lemma = conf_matrix(token, token_gold, "lemma", lemma, lemma_gold)
# Out:
# Token : des | Token Gold : des | lemma : du | lemma Gold : des
# Token : autres | Token Gold : autres | lemma : autre | lemma Gold : autre
# Token : Faria | Token Gold : Faria | lemma : Faria | lemma Gold : Faria
# Token : que | Token Gold : que | lemma : que | lemma Gold : que
# Token : toutes | Token Gold : toutes | lemma : tout | lemma Gold : tout
# Token : que | Token Gold : que | lemma : que | lemma Gold : que
# Token : -Vous | Token Gold : -Vous | lemma : -Vous | lemma Gold : -Vous
# Token : Dantès | Token Gold : Dantès | lemma : Dantès | lemma Gold : Dantès
# Token : soupirant | Token Gold : soupirant | lemma : soupirant | lemma Gold : soupirer
# Token : tous | Token Gold : tous | lemma : tout | lemma Gold : tout
# Token : --Puis | Token Gold : --Puis | lemma : --Puis | lemma Gold : --Puis
# Token : qu' | Token Gold : qu' | lemma : que | lemma Gold : que
# Token : --Que | Token Gold : --Que | lemma : --Que | lemma Gold : --Que
# Token : --J'écrivais | Token Gold : --J' | lemma : --J'écrivais | lemma Gold : Je
# Token : nan | Token Gold : écrivais | lemma : nan | lemma Gold : écrire
# Token : -On | Token Gold : -On | lemma : -On | lemma Gold : -On
# Token : --Non | Token Gold : --Non | lemma : --Non | lemma Gold : --Non
# Token : - | Token Gold : nan | lemma : - | lemma Gold : nan
# Token : --Vous | Token Gold : --Vous | lemma : --Vous | lemma Gold : --Vous
# Token : Dantès | Token Gold : Dantès | lemma : Dantès | lemma Gold : Dantès
# Token : --Oui | Token Gold : --Oui | lemma : --Oui | lemma Gold : --Oui
# Token : Dantès | Token Gold : Dantès | lemma : Dantès | lemma Gold : Dantès
# Token : Faria | Token Gold : Faria | lemma : Faria | lemma Gold : Faria
# Token : dit-il | Token Gold : dit | lemma : dit-il | lemma Gold : Dire
# Token : nan | Token Gold : -il | lemma : nan | lemma Gold : il
# Token : toute | Token Gold : toute | lemma : tout | lemma Gold : tout
# Token : que | Token Gold : que | lemma : que | lemma Gold : que
# Token : Italie_ | Token Gold : Italie_ | lemma : Italie_ | lemma Gold : Italie_
# Token : --Et | Token Gold : --Et | lemma : --Et | lemma Gold : --Et
# Token : --Sur | Token Gold : --Sur | lemma : --Sur | lemma Gold : --Sur
# Token : -Vous | Token Gold : -Vous | lemma : -Vous | lemma Gold : -Vous
# Token : --Un | Token Gold : --Un | lemma : --Un | lemma Gold : --Un
# Token : --Mais | Token Gold : --Mais | lemma : --Mais | lemma Gold : --Mais
# Token : des | Token Gold : des | lemma : du | lemma Gold : des
# Token : des | Token Gold : des | lemma : du | lemma Gold : des
# Token : --À | Token Gold : --À | lemma : --À | lemma Gold : --À
# Token : les | Token Gold : les | lemma : le | lemma Gold : la|le
# Token : lire | Token Gold : lire | lemma : lire | lemma Gold : lire
# Token : cinquante | Token Gold : cinquante | lemma : cinquante | lemma Gold : cinquante
# Token : cinquante | Token Gold : cinquante | lemma : cinquante | lemma Gold : cinquante
# Token : que | Token Gold : que | lemma : que | lemma Gold : que
# Token : --Mais | Token Gold : --Mais | lemma : --Mais | lemma Gold : --Mais
# Token : plusieurs | Token Gold : plusieurs | lemma : plusieurs | lemma Gold : plusieurs
# Token : -Je | Token Gold : -Je | lemma : -Je | lemma Gold : -Je
# Token : français | Token Gold : français | lemma : français | lemma Gold : français
# Token : italien | Token Gold : italien | lemma : italien | lemma Gold : italien
# Token : anglais | Token Gold : anglais | lemma : anglais | lemma Gold : anglais
# Token : espagnol | Token Gold : espagnol | lemma : espagnol | lemma Gold : espagnol
# Token : -Vous | Token Gold : -Vous | lemma : -Vous | lemma Gold : -Vous
# Token : Dantès | Token Gold : Dantès | lemma : Dantès | lemma Gold : Dantès
# Token : --Oui | Token Gold : --Oui | lemma : --Oui | lemma Gold : --Oui
# Token : qu' | Token Gold : qu' | lemma : que | lemma Gold : que
# Token : tout | Token Gold : tout | lemma : tout | lemma Gold : tout
# Token : quoiqu'il | Token Gold : Quoique | lemma : quoiqu'il | lemma Gold : quoique
# Token : nan | Token Gold : Il | lemma : nan | lemma Gold : Il
# Token : Edmond | Token Gold : Edmond | lemma : Edmond | lemma Gold : Edmond
# Token : l' | Token Gold : l' | lemma : la|le | lemma Gold : la|le
# Token : dit-il | Token Gold : dit | lemma : dit-il | lemma Gold : dire
# Token : nan | Token Gold : -il | lemma : nan | lemma Gold : -il
# Token : quoi | Token Gold : quoi | lemma : quoi | lemma Gold : quoi
# Token : -Je | Token Gold : -Je | lemma : -Je | lemma Gold : -Je
# Token : l' | Token Gold : l' | lemma : la|le | lemma Gold : la|le
# Token : Aussi | Token Gold : Aussi | lemma : aussi | lemma Gold : aussi
# Token : descendant | Token Gold : descendant | lemma : descendant | lemma Gold : descendre
# Token : présent | Token Gold : présent | lemma : présent | lemma Gold : présent
# Token : --Mais | Token Gold : --Mais | lemma : --Mais | lemma Gold : --Mais
# Token : Dantès | Token Gold : Dantès | lemma : Dantès | lemma Gold : Dantès
# Token : --Il | Token Gold : --Il | lemma : --Il | lemma Gold : --Il
# Token : Faria | Token Gold : Faria | lemma : Faria | lemma Gold : Faria
# Token : quelque | Token Gold : quelque | lemma : quelque | lemma Gold : quelque
# Token : tous | Token Gold : tous | lemma : tout | lemma Gold : tout
# Token : --Et | Token Gold : --Et | lemma : --Et | lemma Gold : --Et
# Token : tout | Token Gold : tout | lemma : tout | lemma Gold : tout
# Token : Dantès | Token Gold : Dantès | lemma : Dantès | lemma Gold : Dantès
# Token : --Quand | Token Gold : --Quand | lemma : --Quand | lemma Gold : --Quand
# Token : Faria | Token Gold : Faria | lemma : Faria | lemma Gold : Faria
# Token : --Oh | Token Gold : --Oh | lemma : --Oh | lemma Gold : --Oh
# Token : Dantès | Token Gold : Dantès | lemma : Dantès | lemma Gold : Dantès

# %%
p_token, r_token, fscore_token = p_r_fscore(vp_token, fp_token, fn_token)
p_pos, r_pos, fscore_pos = p_r_fscore(vp_pos, fp_pos, fn_pos)
p_lemma, r_lemma, fscore_lemma = p_r_fscore(vp_lemma, fp_lemma, fn_lemma)

# %%
print(f'Pour annotation POS : P = {round(p_pos,5)} | R = {round(r_pos,5)} | f-score = {round(fscore_pos,5)}')
print(f'Pour annotation lemma : P = {round(p_lemma,5)} | R = {round(r_lemma,5)} | f-score = {round(fscore_lemma,5)}')
print(f'Pour tokenisation : P = {round(p_token,5)} | R = {round(r_token,5)} | f-score = {round(fscore_token,5)}')
# Out:
# Pour annotation POS : P = 0.93588 | R = 0.99631 | f-score = 0.96515
# Pour annotation lemma : P = 0.93588 | R = 0.99631 | f-score = 0.96515
# Pour tokenisation : P = 0.99567 | R = 0.99653 | f-score = 0.9961

# %% [markdown]
# # SEM

# %% [markdown]
# Puisque le logiciel ne génère que le résultat au format texte brut, nous avons donc dû établir un script permettant de le convertir en fichier CSV, ce qui rend adaptable au traitement dans le module PANDAS.

# %%
import csv

#with open('/content/sem_lzFne2.text','r',encoding = 'utf-8') as infile:
#  txt = infile.read()

#header = ["TOKEN", "POS"]

#with open('sem_output.csv', 'w', newline='') as outfile:
#    writer = csv.writer(outfile)
#    writer.writerow(header)
#    for line in txt.split(' '):
#        # on divise ici les deux attributs par l'espace
#        fields = line.strip().split('/')   
#        writer.writerow(fields)

# %%
sem_df = pd.read_csv('data/sem_output.csv', sep = ',')
gold_df = pd.read_csv('data/sem_output_gold.csv', sep = ',')

token = sem_df['TOKEN']
pos = sem_df['POS']
token_gold = gold_df['TOKEN_GOLD']
pos_gold = gold_df['POS_GOLD']

# %%
vp_token, fp_token, fn_token = conf_matrix_token(token, token_gold)
# Out:
# Token : en_effet | Token Gold : en
# Token : nan | Token Gold : effet
# Token : il_y_a | Token Gold : il
# Token : nan | Token Gold : y
# Token : nan | Token Gold : a
# Token : Et_puis | Token Gold : Et
# Token : nan | Token Gold : puis
# Token : Il_y_a | Token Gold : il
# Token : nan | Token Gold : y
# Token : nan | Token Gold : a
# Token : celles-là | Token Gold : celles-
# Token : nan | Token Gold : -là
# Token : croyez-moi | Token Gold : Croyez
# Token : nan | Token Gold : -moi
# Token : profitons-en | Token Gold : Profitons
# Token : nan | Token Gold : -en
# Token : point_qu' | Token Gold : point
# Token : nan | Token Gold : _qu'
# Token : -J' | Token Gold : --J'
# Token : -Non | Token Gold : --Non
# Token : vous_faites_du | Token Gold : vous
# Token : nan | Token Gold : faites
# Token : nan | Token Gold : du
# Token : Faria | Token Gold :
# Faria
# Token : à_l'_ombre_du | Token Gold : à
# Token : nan | Token Gold : l'
# Token : nan | Token Gold : ombre
# Token : nan | Token Gold : du
# Token : au_pied_de | Token Gold : au
# Token : nan | Token Gold : pied
# Token : nan | Token Gold : de
# Token : -Un_peu | Token Gold : Un
# Token : nan | Token Gold : peu
# Token : à_peu_près | Token Gold : à
# Token : nan | Token Gold : peu
# Token : nan | Token Gold : près
# Token : cinq_mille | Token Gold : cinq
# Token : nan | Token Gold : mille
# Token : cent_cinquante | Token Gold : cent
# Token : nan | Token Gold : cinquante
# Token : bien_choisis | Token Gold : bien
# Token : nan | Token Gold : choisis
# Token : du_moins | Token Gold : du
# Token : nan | Token Gold : moins
# Token : ces_cent_cinquante | Token Gold : ces
# Token : nan | Token Gold : cent
# Token : nan | Token Gold : cinquante
# Token : à_peu_près_par_coeur | Token Gold : à
# Token : nan | Token Gold : peu
# Token : nan | Token Gold : près
# Token : nan | Token Gold : par
# Token : nan | Token Gold : coeur
# Token : tout_à_fait | Token Gold : tout
# Token : nan | Token Gold : à
# Token : nan | Token Gold : fait
# Token : en_ce_moment | Token Gold : en
# Token : nan | Token Gold : ce
# Token : nan | Token Gold : moment
# Token : nan | Token Gold : dit
# Token : à_peu_près | Token Gold : à
# Token : nan | Token Gold : peu
# Token : nan | Token Gold : près
# Token : ait_cent_mille | Token Gold : ait
# Token : nan | Token Gold : cent
# Token : nan | Token Gold : mille
# Token : De_plus_en_plus | Token Gold : de
# Token : nan | Token Gold : plus
# Token : nan | Token Gold : en
# Token : nan | Token Gold : plus
# Token : en_défaut | Token Gold : en
# Token : nan | Token Gold : défaut
# Token : en_suis | Token Gold : en
# Token : nan | Token Gold : suis
# Token : dans_le_passé | Token Gold : dans
# Token : nan | Token Gold : le
# Token : nan | Token Gold : passé
# Token : quelque_temps | Token Gold : quelque
# Token : nan | Token Gold : temps
# Token : sans_doute | Token Gold : sans
# Token : nan | Token Gold : doute
# Token : tout_l'_intérieur | Token Gold : tout
# Token : nan | Token Gold : l’
# Token : nan | Token Gold : intérieur
# Token : -Et_quand_pourrai | Token Gold : -Et
# Token : nan | Token Gold : quand
# Token : nan | Token Gold : pourrai
# Token : tout_de_suite | Token Gold : tout
# Token : nan | Token Gold : de
# Token : nan | Token Gold : suite
# Token : -Suivez-moi | Token Gold : -Suivez
# Token : nan | Token Gold : -moi

# %%
vp_pos, fp_pos, fn_pos = conf_matrix(token, token_gold, "POS", pos, pos_gold)
# Out:
# Token : ﻿Dantès | Token Gold : ﻿Dantès | POS : NC | POS Gold : NPP
# Token : en_effet | Token Gold : en | POS : ADV | POS Gold : P
# Token : nan | Token Gold : effet | POS : nan | POS Gold : NC
# Token : il_y_a | Token Gold : il | POS : P | POS Gold : CLS
# Token : nan | Token Gold : y | POS : nan | POS Gold : CLO
# Token : nan | Token Gold : a | POS : nan | POS Gold : V
# Token : Et_puis | Token Gold : Et | POS : CC | POS Gold : CC
# Token : nan | Token Gold : puis | POS : nan | POS Gold : CC
# Token : continua | Token Gold : continua | POS : P | POS Gold : V
# Token : Latude | Token Gold : Latude | POS : NC | POS Gold : NPP
# Token : Il_y_a | Token Gold : il | POS : P | POS Gold : CLS
# Token : nan | Token Gold : y | POS : nan | POS Gold : CLO
# Token : nan | Token Gold : a | POS : nan | POS Gold : V
# Token : celles-là | Token Gold : celles- | POS : PRO | POS Gold : PRO
# Token : nan | Token Gold : -là | POS : nan | POS Gold : ADV
# Token : attendons | Token Gold : attendons | POS : NC | POS Gold : VIMP
# Token : croyez-moi | Token Gold : Croyez | POS : NC | POS Gold : VIMP
# Token : nan | Token Gold : -moi | POS : nan | POS Gold : PRO
# Token : profitons-en | Token Gold : Profitons | POS : NC | POS Gold : VIMP
# Token : nan | Token Gold : -en | POS : nan | POS Gold : PRO
# Token : vous | Token Gold : vous | POS : CLS | POS Gold : CLO
# Token : point_qu' | Token Gold : point | POS : CS | POS Gold : ADV
# Token : nan | Token Gold : _qu' | POS : nan | POS Gold : CS
# Token : -J' | Token Gold : --J' | POS : DET | POS Gold : CLS
# Token : écrivais | Token Gold : écrivais | POS : NC | POS Gold : V
# Token : -Non | Token Gold : --Non | POS : NC | POS Gold : NC
# Token : m' | Token Gold : m' | POS : V | POS Gold : CLO
# Token : fais | Token Gold : fais | POS : NC | POS Gold : V
# Token : vous_faites_du | Token Gold : vous | POS : P | POS Gold : CLO
# Token : nan | Token Gold : faites | POS : nan | POS Gold : V
# Token : nan | Token Gold : du | POS : nan | POS Gold : P+D
# Token : s' | Token Gold : s' | POS : CLR | POS Gold :
# CLR
# Token : -Oui | Token Gold : -Oui | POS : NC | POS Gold : ADV
# Token : » | Token Gold : » | POS : DET | POS Gold : PONCT
# Token : peine | Token Gold : peine | POS : VPP | POS Gold : NC
# Token : Faria | Token Gold :
# Faria | POS : NPP | POS Gold :
# NPP
# Token : des | Token Gold : des | POS : DET | POS Gold : P+D
# Token : à_l'_ombre_du | Token Gold : à | POS : P | POS Gold : P
# Token : nan | Token Gold : l' | POS : nan | POS Gold : DET
# Token : nan | Token Gold : ombre | POS : nan | POS Gold : NC
# Token : nan | Token Gold : du | POS : nan | POS Gold : P+D
# Token : Colisée | Token Gold : Colisée | POS : NC | POS Gold : NPP
# Token : au_pied_de | Token Gold : au | POS : P | POS Gold : P+D
# Token : nan | Token Gold : pied | POS : nan | POS Gold : NC
# Token : nan | Token Gold : de | POS : nan | POS Gold : P
# Token : -Et | Token Gold : -Et | POS : CLS | POS Gold : CC
# Token : ? | Token Gold : ? | POS : PONCT
# - | POS Gold : PONCT
# Token : uni | Token Gold : uni | POS : VPP | POS Gold : ADJ
# Token : comme | Token Gold : comme | POS : P | POS Gold : CC
# Token : -Un_peu | Token Gold : Un | POS : ADV | POS Gold : DET
# Token : nan | Token Gold : peu | POS : nan | POS Gold : ADV
# Token : Cabanis | Token Gold : Cabanis | POS : NC | POS Gold : NPP
# Token : -Mais | Token Gold : -Mais | POS : NC | POS Gold : CC
# Token : à_peu_près | Token Gold : à | POS : ADV | POS Gold : P
# Token : nan | Token Gold : peu | POS : nan | POS Gold : ADV
# Token : nan | Token Gold : près | POS : nan | POS Gold : ADV
# Token : cinq_mille | Token Gold : cinq | POS : DET | POS Gold : DET
# Token : nan | Token Gold : mille | POS : nan | POS Gold : DET
# Token : relire | Token Gold : relire | POS : NC | POS Gold : V
# Token : cent_cinquante | Token Gold : cent | POS : DET | POS Gold : DET
# Token : nan | Token Gold : cinquante | POS : nan | POS Gold : DET
# Token : bien_choisis | Token Gold : bien | POS : CS | POS Gold : ADV
# Token : nan | Token Gold : choisis | POS : nan | POS Gold : VPP
# Token : du_moins | Token Gold : du | POS : ADV | POS Gold : P
# Token : nan | Token Gold : moins | POS : nan | POS Gold : ADV
# Token : ces_cent_cinquante | Token Gold : ces | POS : DET | POS Gold : DET
# Token : nan | Token Gold : cent | POS : nan | POS Gold : DET
# Token : nan | Token Gold : cinquante | POS : nan | POS Gold : DET
# Token : à_peu_près_par_coeur | Token Gold : à | POS : ADV | POS Gold : P
# Token : nan | Token Gold : peu | POS : nan | POS Gold : ADV
# Token : nan | Token Gold : près | POS : nan | POS Gold : ADV
# Token : nan | Token Gold : par | POS : nan | POS Gold : P
# Token : nan | Token Gold : coeur | POS : nan | POS Gold : NC
# Token : me | Token Gold : me | POS : V | POS Gold : CLR
# Token : les | Token Gold : les | POS : DET | POS Gold : CLO
# Token : tout_à_fait | Token Gold : tout | POS : ADV | POS Gold : adv
# Token : nan | Token Gold : à | POS : nan | POS Gold : P
# Token : nan | Token Gold : fait | POS : nan | POS Gold : ADV
# Token : que | Token Gold : que | POS : CS | POS Gold : ADV
# Token : -Mais | Token Gold : -Mais | POS : PROREL | POS Gold : CC
# Token : en_ce_moment | Token Gold : en | POS : ADV | POS Gold : P
# Token : nan | Token Gold : ce | POS : nan | POS Gold : DET
# Token : nan | Token Gold : moment | POS : nan | POS Gold : NC
# Token : nan | Token Gold : dit | POS : nan | POS Gold :
# V
# Token : -Oui | Token Gold : -Oui | POS : NC | POS Gold : ADV
# Token : à_peu_près | Token Gold : à | POS : ADV | POS Gold : P
# Token : nan | Token Gold : peu | POS : nan | POS Gold : ADV
# Token : nan | Token Gold : près | POS : nan | POS Gold : ADV
# Token : ait_cent_mille | Token Gold : ait | POS : ADJ | POS Gold : V
# Token : nan | Token Gold : cent | POS : nan | POS Gold : DET
# Token : nan | Token Gold : mille | POS : nan | POS Gold : DET
# Token : De_plus_en_plus | Token Gold : de | POS : NC | POS Gold : P
# Token : nan | Token Gold : plus | POS : nan | POS Gold : ADV
# Token : nan | Token Gold : en | POS : nan | POS Gold : P
# Token : nan | Token Gold : plus | POS : nan | POS Gold : ADV
# Token : en_défaut | Token Gold : en | POS : ADV | POS Gold : P
# Token : nan | Token Gold : défaut | POS : nan | POS Gold : NC
# Token : l' | Token Gold : l' | POS : CLO | POS Gold : DET
# Token : m' | Token Gold : m' | POS : V | POS Gold : CLR
# Token : en_suis | Token Gold : en | POS : ADV | POS Gold : CLR
# Token : nan | Token Gold : suis | POS : nan | POS Gold : V
# Token : excellentes | Token Gold : excellentes | POS : NC | POS Gold : ADJ
# Token : dans_le_passé | Token Gold : dans | POS : ADV | POS Gold : P
# Token : nan | Token Gold : le | POS : nan | POS Gold : DET
# Token : nan | Token Gold : passé | POS : nan | POS Gold : NC
# Token : ? | Token Gold : ? | POS : PONCT
# dit | POS Gold : PONCT
# Token : dit | Token Gold : dit | POS : V | POS Gold :
# V
# Token : quelque_temps | Token Gold : quelque | POS : ADV | POS Gold : ADV
# Token : nan | Token Gold : temps | POS : nan | POS Gold : NC
# Token : sans_doute | Token Gold : sans | POS : ADV | POS Gold : P
# Token : nan | Token Gold : doute | POS : nan | POS Gold : NC
# Token : y | Token Gold : y | POS : CLO | POS Gold : ADV
# Token : du | Token Gold : du | POS : P+D | POS Gold : DET
# Token : tout_l'_intérieur | Token Gold : tout | POS : ADV | POS Gold : ADJ
# Token : nan | Token Gold : l’ | POS : nan | POS Gold : DET
# Token : nan | Token Gold : intérieur | POS : nan | POS Gold : NC
# Token : -Et_quand_pourrai | Token Gold : -Et | POS : ADV | POS Gold : CC
# Token : nan | Token Gold : quand | POS : nan | POS Gold : PROWH
# Token : nan | Token Gold : pourrai | POS : nan | POS Gold : V
# Token : tout_de_suite | Token Gold : tout | POS : ADV | POS Gold : ADV
#
# Token : nan | Token Gold : de | POS : nan | POS Gold : P
# Token : nan | Token Gold : suite | POS : nan | POS Gold : NC
# Token : s' | Token Gold : s' | POS : CLR | POS Gold :
# CLR
# Token : -Suivez-moi | Token Gold : -Suivez | POS : CLS | POS Gold : VIMP
# Token : nan | Token Gold : -moi | POS : nan | POS Gold : CLO
# Token : . | Token Gold : . | POS : PONCT
# Et | POS Gold : PONCT

# %%
p_token, r_token, fscore_token = p_r_fscore(vp_token, fp_token, fn_token)
p_pos, r_pos, fscore_pos = p_r_fscore(vp_pos, fp_pos, fn_pos)
p_lemma, r_lemma, fscore_lemma = p_r_fscore(vp_lemma, fp_lemma, fn_lemma)

# %%
print(f'Pour annotation POS : P = {round(p_pos,3)} | R = {round(r_pos,3)} | f-score = {round(fscore_pos,3)}')
print(f'Pour annotation lemma : P = {round(p_lemma,3)} | R = {round(r_lemma,3)} | f-score = {round(fscore_lemma,3)}')
print(f'Pour tokenisation : P = {round(p_token,3)} | R = {round(r_token,3)} | f-score = {round(fscore_token,3)}')
# Out:
# Pour annotation POS : P = 0.943 | R = 0.95 | f-score = 0.946
# Pour annotation lemma : P = 0.936 | R = 0.996 | f-score = 0.965
# Pour tokenisation : P = 0.968 | R = 0.951 | f-score = 0.959

# %%
print(f'Pour annotation POS : P = {round(p_pos,5)} | R = {round(r_pos,5)} | f-score = {round(fscore_pos,5)}')
print(f'Pour annotation lemma : P = {round(p_lemma,5)} | R = {round(r_lemma,5)} | f-score = {round(fscore_lemma,5)}')
print(f'Pour tokenisation : P = {round(p_token,5)} | R = {round(r_token,5)} | f-score = {round(fscore_token,5)}')
# Out:
# Pour annotation POS : P = 0.94288 | R = 0.94977 | f-score = 0.94631
# Pour annotation lemma : P = 0.93588 | R = 0.99631 | f-score = 0.96515
# Pour tokenisation : P = 0.9676 | R = 0.95133 | f-score = 0.95939
